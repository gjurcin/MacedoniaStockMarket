# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import math
import itertools
import regex as re

import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler, normalize
from sklearn.model_selection import train_test_split, GridSearchCV

from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, LSTM, SimpleRNN, Activation, Dropout, RepeatVector
from keras.metrics import RootMeanSquaredError
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Loading Preprocessed Dataset

# %%
df = pd.read_csv('C:/Users/Gj/Documents/Git/macedonian_stock_exchange_market/tmp/mse_raw.csv', parse_dates=['date', 'start_date'], index_col='Unnamed: 0')

# %%
df.head(5)
# Out:
#    stock_id       date    open    high     low  average   close    volume  \
# 0       ALK 1997-01-09  1070.0  1070.0  1070.0   1070.0  1070.0  279270.0
# 22      ALK 1997-01-10  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 44      ALK 1997-01-11  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 66      ALK 1997-01-12  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 88      ALK 1997-01-13  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
#
#     quantity  change %  volume total start_date
# 0      261.0       0.0      279270.0 1997-01-09
# 22       0.0       0.0           0.0 1997-01-09
# 44       0.0       0.0           0.0 1997-01-09
# 66       0.0       0.0           0.0 1997-01-09
# 88       0.0       0.0           0.0 1997-01-09

# %% [markdown]
# ### setting RNN ALK dataset for training, validation and test

# %%
alk_df = df[df.stock_id == 'ALK']

# %%
alk_df.columns
# Out:
# Index(['stock_id', 'date', 'open', 'high', 'low', 'average', 'close', 'volume',
#        'quantity', 'change %', 'volume total', 'start_date'],
#       dtype='object')

# %% [markdown]
# ### split dataset

# %%
#Create a new dataframe with only closing price column
close_price = alk_df['close']

#Convert the dataframe into numpy array
close_price = close_price.values

# %%
close_price.shape
# Out:
# (8630,)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
scaled_df = scaler.fit_transform(close_price.reshape(len(close_price), 1))

# %%
scaled_df
# Out:
# array([[0.04175824],
#        [0.04175824],
#        [0.04175824],
#        ...,
#        [0.86373626],
#        [0.86373626],
#        [0.85714286]])

# %% [markdown]
# ### univariate sequence

# %%
# split a univariate sequence into samples with one day prediciton
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# choose a number of time steps
n_steps = 3
# split into samples
X, y = split_sequence(scaled_df, n_steps)
# summarize the data
for i in range(3):
    print(X[i], y[i])
# Out:
# [[0.04175824]
#  [0.04175824]
#  [0.04175824]] [0.04175824]
# [[0.04175824]
#  [0.04175824]
#  [0.04175824]] [0.04175824]
# [[0.04175824]
#  [0.04175824]
#  [0.04175824]] [0.04029304]

# %% [markdown]
# ### Vanilla LSTM, one day prediciton

# %%
X_train, X_valid, X_test = X[:int(len(X)-60),], X[int(len(X)-60):int(len(X)-1),], X[int(len(X)-1):,]
y_train, y_valid, y_test = y[:int(len(X)-60),], y[int(len(X)-60):int(len(X)-1),], y[int(len(X)-1):,]

# %%
X_train.shape, X_valid.shape, X_test.shape, y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((8567, 3, 1), (59, 3, 1), (1, 3, 1), (8567, 1), (59, 1), (1, 1))

# %%
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
X_valid = X_valid.reshape((X_valid.shape[0], X_valid.shape[1], n_features))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

# %%
from keras import backend as K
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))
    
rmse = RootMeanSquaredError()

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
my_callback1 = ModelCheckpoint('vanila_best.pt', verbose=1, save_best_only=True, mode='min', monitor='val_loss')
my_callback2 = EarlyStopping(patience=15)

my_callbacks = [my_callback1, my_callback2]

# %%
# fit model
history = model.fit(X_train, y_train, epochs=50, callbacks=my_callbacks, validation_data=[X_valid, y_valid])
# Out:
# Train on 8567 samples, validate on 59 samples
# Epoch 1/50
# 8567/8567 [==============================] - 2s 257us/step - loss: 0.0139 - val_loss: 3.3662e-04
#
# Epoch 00001: val_loss improved from inf to 0.00034, saving model to vanila_best.pt
# Epoch 2/50
# 8567/8567 [==============================] - 2s 184us/step - loss: 7.8924e-05 - val_loss: 1.0230e-04
#
# Epoch 00002: val_loss improved from 0.00034 to 0.00010, saving model to vanila_best.pt
# Epoch 3/50
# 8567/8567 [==============================] - 2s 185us/step - loss: 7.6187e-05 - val_loss: 9.7811e-05
#
# Epoch 00003: val_loss improved from 0.00010 to 0.00010, saving model to vanila_best.pt
# Epoch 4/50
# 8567/8567 [==============================] - 2s 190us/step - loss: 7.5877e-05 - val_loss: 5.5492e-05
#
# Epoch 00004: val_loss improved from 0.00010 to 0.00006, saving model to vanila_best.pt
# Epoch 5/50
# 8567/8567 [==============================] - 2s 189us/step - loss: 7.5668e-05 - val_loss: 7.9617e-05
#
# Epoch 00005: val_loss did not improve from 0.00006
# Epoch 6/50
# 8567/8567 [==============================] - 2s 191us/step - loss: 7.4288e-05 - val_loss: 5.4752e-05
#
# Epoch 00006: val_loss improved from 0.00006 to 0.00005, saving model to vanila_best.pt
# Epoch 7/50
# 8567/8567 [==============================] - 2s 185us/step - loss: 7.5639e-05 - val_loss: 6.3382e-05
#
# Epoch 00007: val_loss did not improve from 0.00005
# Epoch 8/50
# 8567/8567 [==============================] - 2s 184us/step - loss: 7.4299e-05 - val_loss: 5.4409e-05
#
# Epoch 00008: val_loss improved from 0.00005 to 0.00005, saving model to vanila_best.pt
# Epoch 9/50
# 8567/8567 [==============================] - 2s 187us/step - loss: 7.2042e-05 - val_loss: 7.3604e-05
#
# Epoch 00009: val_loss did not improve from 0.00005
# Epoch 10/50
# 8567/8567 [==============================] - 2s 191us/step - loss: 7.4840e-05 - val_loss: 6.3886e-05
#
# Epoch 00010: val_loss did not improve from 0.00005
# Epoch 11/50
# 8567/8567 [==============================] - 2s 214us/step - loss: 7.2418e-05 - val_loss: 8.9115e-05
#
# Epoch 00011: val_loss did not improve from 0.00005
# Epoch 12/50
# 8567/8567 [==============================] - 2s 223us/step - loss: 7.2997e-05 - val_loss: 1.4670e-04
#
# Epoch 00012: val_loss did not improve from 0.00005
# Epoch 13/50
# 8567/8567 [==============================] - 2s 209us/step - loss: 7.3927e-05 - val_loss: 5.8451e-05
#
# Epoch 00013: val_loss did not improve from 0.00005
# Epoch 14/50
# 8567/8567 [==============================] - 2s 198us/step - loss: 7.2333e-05 - val_loss: 5.7725e-05
#
# Epoch 00014: val_loss did not improve from 0.00005
# Epoch 15/50
# 8567/8567 [==============================] - 2s 188us/step - loss: 7.4890e-05 - val_loss: 7.0969e-05
#
# Epoch 00015: val_loss did not improve from 0.00005
# Epoch 16/50
# 8567/8567 [==============================] - 2s 199us/step - loss: 7.0761e-05 - val_loss: 2.0767e-04
#
# Epoch 00016: val_loss did not improve from 0.00005
# Epoch 17/50
# 8567/8567 [==============================] - 2s 192us/step - loss: 7.0458e-05 - val_loss: 1.0001e-04
#
# Epoch 00017: val_loss did not improve from 0.00005
# Epoch 18/50
# 8567/8567 [==============================] - 2s 192us/step - loss: 7.0457e-05 - val_loss: 9.3620e-05
#
# Epoch 00018: val_loss did not improve from 0.00005
# Epoch 19/50
# 8567/8567 [==============================] - 2s 192us/step - loss: 7.5212e-05 - val_loss: 5.7922e-05
#
# Epoch 00019: val_loss did not improve from 0.00005
# Epoch 20/50
# 8567/8567 [==============================] - 2s 198us/step - loss: 6.8697e-05 - val_loss: 7.6857e-05
#
# Epoch 00020: val_loss did not improve from 0.00005
# Epoch 21/50
# 8567/8567 [==============================] - 2s 195us/step - loss: 6.8778e-05 - val_loss: 8.0967e-05
#
# Epoch 00021: val_loss did not improve from 0.00005
# Epoch 22/50
# 8567/8567 [==============================] - 2s 192us/step - loss: 6.6177e-05 - val_loss: 1.1255e-04
#
# Epoch 00022: val_loss did not improve from 0.00005
# Epoch 23/50
# 8567/8567 [==============================] - 2s 205us/step - loss: 6.3239e-05 - val_loss: 6.8581e-05
#
# Epoch 00023: val_loss did not improve from 0.00005

# %%
# plot train and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
yhat = model.predict(X_test, verbose=0)

# %%
y_actual = scaler.inverse_transform(y_test)
y_pred = scaler.inverse_transform(yhat)

# %%
np.sqrt(mean_squared_error(y_actual, y_pred))
# Out:
# 46.7890625

# %% [markdown]
# ### Stacked LSTM, one day prediciton

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
# fit model
history = model.fit(X_train, y_train, 
                    epochs=50, 
                    callbacks=my_callbacks, 
                    validation_data=[X_valid, y_valid])
# Out:
# Train on 8567 samples, validate on 59 samples
# Epoch 1/50
# 8567/8567 [==============================] - 4s 445us/step - loss: 0.0102 - val_loss: 2.2322e-04
#
# Epoch 00001: val_loss did not improve from 0.00005
# Epoch 2/50
# 8567/8567 [==============================] - 2s 284us/step - loss: 1.0777e-04 - val_loss: 7.9504e-05
#
# Epoch 00002: val_loss did not improve from 0.00005
# Epoch 3/50
# 8567/8567 [==============================] - 2s 287us/step - loss: 9.8058e-05 - val_loss: 7.2033e-05
#
# Epoch 00003: val_loss did not improve from 0.00005
# Epoch 4/50
# 8567/8567 [==============================] - 2s 290us/step - loss: 1.0802e-04 - val_loss: 1.4977e-04
#
# Epoch 00004: val_loss did not improve from 0.00005
# Epoch 5/50
# 8567/8567 [==============================] - 2s 288us/step - loss: 1.0186e-04 - val_loss: 1.0204e-04
#
# Epoch 00005: val_loss did not improve from 0.00005
# Epoch 6/50
# 8567/8567 [==============================] - 2s 290us/step - loss: 9.5288e-05 - val_loss: 7.3235e-04
#
# Epoch 00006: val_loss did not improve from 0.00005
# Epoch 7/50
# 8567/8567 [==============================] - 3s 296us/step - loss: 1.0218e-04 - val_loss: 9.9291e-05
#
# Epoch 00007: val_loss did not improve from 0.00005
# Epoch 8/50
# 8567/8567 [==============================] - 3s 300us/step - loss: 1.0098e-04 - val_loss: 6.4759e-05
#
# Epoch 00008: val_loss did not improve from 0.00005
# Epoch 9/50
# 8567/8567 [==============================] - 3s 318us/step - loss: 1.0177e-04 - val_loss: 1.5213e-04
#
# Epoch 00009: val_loss did not improve from 0.00005
# Epoch 10/50
# 8567/8567 [==============================] - 3s 335us/step - loss: 9.9777e-05 - val_loss: 1.7164e-04
#
# Epoch 00010: val_loss did not improve from 0.00005
# Epoch 11/50
# 8567/8567 [==============================] - 3s 328us/step - loss: 9.3450e-05 - val_loss: 2.0195e-04
#
# Epoch 00011: val_loss did not improve from 0.00005
# Epoch 12/50
# 8567/8567 [==============================] - 3s 335us/step - loss: 9.4768e-05 - val_loss: 9.7805e-05
#
# Epoch 00012: val_loss did not improve from 0.00005
# Epoch 13/50
# 8567/8567 [==============================] - 3s 339us/step - loss: 9.6596e-05 - val_loss: 6.0930e-05
#
# Epoch 00013: val_loss did not improve from 0.00005
# Epoch 14/50
# 8567/8567 [==============================] - 3s 307us/step - loss: 9.4873e-05 - val_loss: 8.5408e-05
#
# Epoch 00014: val_loss did not improve from 0.00005
# Epoch 15/50
# 8567/8567 [==============================] - 3s 295us/step - loss: 9.4566e-05 - val_loss: 6.1794e-05
#
# Epoch 00015: val_loss did not improve from 0.00005
# Epoch 16/50
# 8567/8567 [==============================] - 3s 292us/step - loss: 9.9163e-05 - val_loss: 9.1897e-05
#
# Epoch 00016: val_loss did not improve from 0.00005
# Epoch 17/50
# 8567/8567 [==============================] - 3s 296us/step - loss: 8.9821e-05 - val_loss: 1.0624e-04
#
# Epoch 00017: val_loss did not improve from 0.00005
# Epoch 18/50
# 8567/8567 [==============================] - 3s 296us/step - loss: 9.1077e-05 - val_loss: 6.2490e-05
#
# Epoch 00018: val_loss did not improve from 0.00005
# Epoch 19/50
# 8567/8567 [==============================] - 3s 297us/step - loss: 8.7836e-05 - val_loss: 6.9120e-05
#
# Epoch 00019: val_loss did not improve from 0.00005
# Epoch 20/50
# 8567/8567 [==============================] - 3s 294us/step - loss: 8.4989e-05 - val_loss: 1.1842e-04
#
# Epoch 00020: val_loss did not improve from 0.00005
# Epoch 21/50
# 8567/8567 [==============================] - 3s 294us/step - loss: 8.8955e-05 - val_loss: 6.6726e-05
#
# Epoch 00021: val_loss did not improve from 0.00005
# Epoch 22/50
# 8567/8567 [==============================] - 3s 294us/step - loss: 8.3921e-05 - val_loss: 7.0939e-05
#
# Epoch 00022: val_loss did not improve from 0.00005
# Epoch 23/50
# 8567/8567 [==============================] - 3s 304us/step - loss: 8.5711e-05 - val_loss: 6.0682e-05
#
# Epoch 00023: val_loss did not improve from 0.00005
# Epoch 24/50
# 8567/8567 [==============================] - 3s 298us/step - loss: 8.5469e-05 - val_loss: 1.0754e-04
#
# Epoch 00024: val_loss did not improve from 0.00005
# Epoch 25/50
# 8567/8567 [==============================] - 3s 300us/step - loss: 7.6586e-05 - val_loss: 6.7190e-05
#
# Epoch 00025: val_loss did not improve from 0.00005
# Epoch 26/50
# 8567/8567 [==============================] - 3s 297us/step - loss: 8.1573e-05 - val_loss: 1.4194e-04
#
# Epoch 00026: val_loss did not improve from 0.00005
# Epoch 27/50
# 8567/8567 [==============================] - 3s 297us/step - loss: 7.4810e-05 - val_loss: 5.2141e-05
#
# Epoch 00027: val_loss improved from 0.00005 to 0.00005, saving model to vanila_best.pt
# Epoch 28/50
# 8567/8567 [==============================] - 3s 303us/step - loss: 7.7611e-05 - val_loss: 5.5687e-05
#
# Epoch 00028: val_loss did not improve from 0.00005
# Epoch 29/50
# 8567/8567 [==============================] - 3s 302us/step - loss: 7.0246e-05 - val_loss: 5.7516e-05
#
# Epoch 00029: val_loss did not improve from 0.00005
# Epoch 30/50
# 8567/8567 [==============================] - 3s 313us/step - loss: 7.2441e-05 - val_loss: 7.3352e-05
#
# Epoch 00030: val_loss did not improve from 0.00005
# Epoch 31/50
# 8567/8567 [==============================] - 3s 303us/step - loss: 7.0939e-05 - val_loss: 9.2854e-05
#
# Epoch 00031: val_loss did not improve from 0.00005
# Epoch 32/50
# 8567/8567 [==============================] - 3s 301us/step - loss: 6.6543e-05 - val_loss: 6.1777e-05
#
# Epoch 00032: val_loss did not improve from 0.00005
# Epoch 33/50
# 8567/8567 [==============================] - 3s 308us/step - loss: 7.1593e-05 - val_loss: 1.1855e-04
#
# Epoch 00033: val_loss did not improve from 0.00005
# Epoch 34/50
# 8567/8567 [==============================] - 3s 296us/step - loss: 6.8268e-05 - val_loss: 5.7221e-05
#
# Epoch 00034: val_loss did not improve from 0.00005
# Epoch 35/50
# 8567/8567 [==============================] - 3s 301us/step - loss: 7.1826e-05 - val_loss: 5.6071e-05
#
# Epoch 00035: val_loss did not improve from 0.00005
# Epoch 36/50
# 8567/8567 [==============================] - 3s 299us/step - loss: 6.8315e-05 - val_loss: 9.3494e-05
#
# Epoch 00036: val_loss did not improve from 0.00005
# Epoch 37/50
# 8567/8567 [==============================] - 3s 302us/step - loss: 6.4296e-05 - val_loss: 6.3358e-05
#
# Epoch 00037: val_loss did not improve from 0.00005
# Epoch 38/50
# 8567/8567 [==============================] - 3s 337us/step - loss: 6.3623e-05 - val_loss: 3.4848e-04
#
# Epoch 00038: val_loss did not improve from 0.00005
# Epoch 39/50
# 8567/8567 [==============================] - 3s 315us/step - loss: 6.2263e-05 - val_loss: 6.3342e-05
#
# Epoch 00039: val_loss did not improve from 0.00005
# Epoch 40/50
# 8567/8567 [==============================] - 3s 314us/step - loss: 6.3180e-05 - val_loss: 9.9086e-05
#
# Epoch 00040: val_loss did not improve from 0.00005
# Epoch 41/50
# 8567/8567 [==============================] - 3s 300us/step - loss: 5.8068e-05 - val_loss: 2.1052e-04
#
# Epoch 00041: val_loss did not improve from 0.00005
# Epoch 42/50
# 8567/8567 [==============================] - 3s 300us/step - loss: 6.1710e-05 - val_loss: 8.0165e-05
#
# Epoch 00042: val_loss did not improve from 0.00005

# %%
# plot train and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
yhat = model.predict(X_test, verbose=0)

# %%
y_actual = scaler.inverse_transform(y_test)
y_pred = scaler.inverse_transform(yhat)
np.sqrt(mean_squared_error(y_actual, y_pred))
# Out:
# 31.44140625

# %% [markdown]
# ### univariate sequence many to many

# %%
# function that segments the data
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the sequence
        if out_end_ix > len(sequence):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 360, 30
n_features = 1

# split the data into samples
X, y = split_sequence(scaled_df, n_steps_in, n_steps_out)

# print the first 3 samples for trainX and trainY
for i in range(3):
    print(X[i], "\n Y: "  ,y[i])
# Out:
# [[0.04175824]
#  [0.04175824]
#  [0.04175824]
#  [0.04175824]
#  [0.04175824]
#  [0.04029304]
#  [0.04029304]
#  [0.03882784]
#  [0.03882784]
#  [0.03882784]
#  [0.03882784]
#  [0.03882784]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.14285714]
#  [0.14285714]
#  [0.14285714]
#  [0.14285714]
#  [0.14285714]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]]
#  Y:  [[0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]]
# [[0.04175824]
#  [0.04175824]
#  [0.04175824]
#  [0.04175824]
#  [0.04029304]
#  [0.04029304]
#  [0.03882784]
#  [0.03882784]
#  [0.03882784]
#  [0.03882784]
#  [0.03882784]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.14285714]
#  [0.14285714]
#  [0.14285714]
#  [0.14285714]
#  [0.14285714]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]]
#  Y:  [[0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]]
# [[0.04175824]
#  [0.04175824]
#  [0.04175824]
#  [0.04029304]
#  [0.04029304]
#  [0.03882784]
#  [0.03882784]
#  [0.03882784]
#  [0.03882784]
#  [0.03882784]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03736264]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03663004]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.14285714]
#  [0.14285714]
#  [0.14285714]
#  [0.14285714]
#  [0.14285714]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]]
#  Y:  [[0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]
#  [0.03443223]]

# %%
X.shape, y.shape
# Out:
# ((8241, 360, 1), (8241, 30, 1))

# %%
X_train, X_valid, X_test = X[:int(len(X)-60),], X[int(len(X)-60):int(len(X)-30),], X[int(len(X)-30):,]
y_train, y_valid, y_test = y[:int(len(X)-60),], y[int(len(X)-60):int(len(X)-30),], y[int(len(X)-30):,]

# %%
X_train.shape, X_valid.shape, X_test.shape, y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((8181, 360, 1),
#  (30, 360, 1),
#  (30, 360, 1),
#  (8181, 30, 1),
#  (30, 30, 1),
#  (30, 30, 1))

# %%
# There are 30 (n_steps_out) predictions for each data point. 
# Thus, we need to take the predicitons on each 'n_steps_out' step 
#X_valid, y_valid = X_valid[:,:n_steps_out], y_valid[:,:n_steps_out]
#X_test, y_test = X_test[:,:n_steps_out], y_test[:,:n_steps_out]

# %%
X_train.shape, X_valid.shape, X_test.shape, y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((8181, 360, 1),
#  (30, 360, 1),
#  (30, 360, 1),
#  (8181, 30, 1),
#  (30, 30, 1),
#  (30, 30, 1))

# %%
# define model
model_many_to_many = Sequential()
model_many_to_many.add(LSTM(30, activation='relu', input_shape=(n_steps_in, n_features)))
model_many_to_many.add(RepeatVector(n_steps_out))
model_many_to_many.add(Dropout(0.2))
model_many_to_many.add(LSTM(5, activation='relu', input_shape=(n_steps_in, n_features)))
model_many_to_many.add(RepeatVector(n_steps_out))
model_many_to_many.add(Dropout(0.2))
model_many_to_many.add(Dense(25))
model_many_to_many.add(Dense(25))
model_many_to_many.add(Dense(1))
model_many_to_many.compile(optimizer='adam', loss='mse')
print(model_many_to_many.summary())
# Out:
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_58 (LSTM)               (None, 30)                3840
# _________________________________________________________________
# repeat_vector_54 (RepeatVect (None, 30, 30)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 30)            0
# _________________________________________________________________
# lstm_59 (LSTM)               (None, 5)                 720
# _________________________________________________________________
# repeat_vector_55 (RepeatVect (None, 30, 5)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30, 5)             0
# _________________________________________________________________
# dense_106 (Dense)            (None, 30, 25)            150
# _________________________________________________________________
# dense_107 (Dense)            (None, 30, 25)            650
# _________________________________________________________________
# dense_108 (Dense)            (None, 30, 1)             26
# =================================================================
# Total params: 5,386
# Trainable params: 5,386
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
my_callback1 = ModelCheckpoint('best_score_30_days.pt', verbose=1, save_best_only=True, mode='min', monitor='val_loss')
my_callback2 = EarlyStopping(patience=2)

my_callbacks = [my_callback1, my_callback2]

# %%
history = model_many_to_many.fit(X_train, y_train,
                                 epochs=5,
                                 batch_size=3,
                                 callbacks=my_callbacks,
                                 verbose=1,
                                 validation_data=(X_valid, y_valid))
# Out:
# Train on 8181 samples, validate on 30 samples
# Epoch 1/5
# 8181/8181 [==============================] - 1111s 136ms/step - loss: 0.0085 - val_loss: 0.0028
#
# Epoch 00001: val_loss improved from inf to 0.00283, saving model to best_score_30_days.pt
# Epoch 2/5
# 8181/8181 [==============================] - 1128s 138ms/step - loss: 0.0077 - val_loss: 0.0014
#
# Epoch 00002: val_loss improved from 0.00283 to 0.00139, saving model to best_score_30_days.pt
# Epoch 3/5
# 8181/8181 [==============================] - 1113s 136ms/step - loss: 0.0075 - val_loss: 7.7432e-04
#
# Epoch 00003: val_loss improved from 0.00139 to 0.00077, saving model to best_score_30_days.pt
# Epoch 4/5
# 8181/8181 [==============================] - 1100s 134ms/step - loss: 0.0057 - val_loss: 0.0058
#
# Epoch 00004: val_loss did not improve from 0.00077
# Epoch 5/5
# 8181/8181 [==============================] - 1121s 137ms/step - loss: 0.0057 - val_loss: 5.8773e-04
#
# Epoch 00005: val_loss improved from 0.00077 to 0.00059, saving model to best_score_30_days.pt

# %%
# plot train and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# make predictions
yhat = model_many_to_many.predict(X_test, verbose=0)

# %%
yhat = yhat.reshape(yhat.shape[0]*yhat.shape[1],1)
y_test = y_test.reshape(y_test.shape[0]*y_test.shape[1],1)

# %%
y_actual = scaler.inverse_transform(y_test)
y_pred = scaler.inverse_transform(yhat)
np.sqrt(mean_squared_error(y_actual, y_pred))
# Out:
# 526.5648914545658

# %%
y_train_pred = model_many_to_many.predict(X_train)
y_train_pred = scaler.inverse_transform(y_train_pred.reshape(y_train_pred.shape[0]*y_train_pred.shape[1],1))

# %%
y_valid_pred = model_many_to_many.predict(X_valid)
y_valid_pred = scaler.inverse_transform(y_valid_pred.reshape(y_valid_pred.shape[0]*y_valid_pred.shape[1],1))

# %%
# plot the test data and predicitons
plt.plot(y_actual[::30])
plt.plot(y_pred[::30])
plt.show()

# %%
y_actual[::30][-1], y_pred[::30][-1]
# Out:
# (array([12750.]), array([12164.129], dtype=float32))

# %%
#plot the data
train_actual = scaler.inverse_transform(y_train.reshape(y_train.shape[0]*y_train.shape[1],1))
valid_actual = scaler.inverse_transform(y_valid.reshape(y_valid.shape[0]*y_valid.shape[1],1))
test_actual = scaler.inverse_transform(y_test.reshape(y_test.shape[0]*y_test.shape[1],1))
all_actual = np.concatenate([train_actual, valid_actual, test_actual], axis=0)
all_prediction = np.concatenate([y_train_pred, y_valid_pred, y_pred], axis=0)
#valid['Predictions'] = predictions
#Visualize the Plot
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Days', fontsize=18)
plt.ylabel('Closing Price in (MKD)', fontsize=18)
plt.plot(all_actual)
plt.plot(all_prediction)
plt.legend(['Train','Val'], loc= 'lower right')
plt.show()

# %%
# calculate root mean squared error on the train, validation and test data
train_score = np.sqrt(mean_squared_error(train_actual, y_train_pred))
print('Train RMSE: %.2f RMSE' % (train_score))
valid_score = np.sqrt(mean_squared_error(valid_actual, y_valid_pred))
print('Validation RMSE: %.2f RMSE' % (valid_score))
test_score = np.sqrt(mean_squared_error(test_actual, y_pred))
print('Test RMSE: %.2f RMSE' % (test_score))
# Out:
# Train RMSE: 535.89 RMSE
# Validation RMSE: 330.92 RMSE
# Test RMSE: 526.56 RMSE
