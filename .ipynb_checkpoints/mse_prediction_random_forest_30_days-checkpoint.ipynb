# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import math
import itertools
import regex as re

import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler, normalize
from sklearn.model_selection import train_test_split, GridSearchCV

from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, LSTM, SimpleRNN, Activation
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Loading Dataset

# %%
stock_exchange_mk = pd.read_csv('data_mse_mse_historic_data_active.csv', sep='\t', parse_dates=['Date'])

# %%
df = pd.DataFrame(stock_exchange_mk)
df["stock_id"] = df["stock_id"].astype('category')
df.columns = df.columns.str.lower()

# %% [markdown]
# # Missing Dates

# %%
stocks = df.stock_id.unique()
dates_all = pd.period_range(min(df.date), max(df.date)).to_timestamp()
idx = pd.MultiIndex.from_product((dates_all, stocks), names=['date', 'stock_id'])
df_new = df.set_index(['date', 'stock_id']).reindex(idx).reset_index()

# %% [markdown]
# ### Drop Unnecessary Dates

# %%
df_list = []
for stock in df.stock_id.unique():
    each_df = df[df.stock_id == stock]
    groupby_stock = each_df.groupby([pd.PeriodIndex(data=each_df.date, freq='D'), 'stock_id'])
    df_list.append(groupby_stock)

# %%
stock_name = []
stock_start_date = []
for i in df_list:
    name = min(i.date)[0][1]
    stock_name.append(name)
    date = min(i.date)[0][0]
    stock_start_date.append(date)
    
start_date = dict(zip(stock_name, stock_start_date))

# %%
start_date_df = pd.DataFrame.from_dict(start_date, orient='index', dtype='datetime64[ns]', columns=['start_date'])

# %%
start_date_df.head()
# Out:
#      start_date
# ALK  1997-01-09
# BESK 2002-10-10
# FERS 1999-04-15
# GRNT 1999-10-28
# KMB  1997-05-15

# %%
df_clean = df_new.set_index('stock_id').join(start_date_df, lsuffix='_filter', on='stock_id').reset_index()

# %%
df_clean.head()
# Out:
#   stock_id       date    open    high     low   close    volume  adj close  \
# 0      ALK 1997-01-09  1070.0  1070.0  1070.0  1070.0  279270.0     1070.0
# 1     BESK 1997-01-09     NaN     NaN     NaN     NaN       NaN        NaN
# 2     FERS 1997-01-09     NaN     NaN     NaN     NaN       NaN        NaN
# 3     GRNT 1997-01-09     NaN     NaN     NaN     NaN       NaN        NaN
# 4      KMB 1997-01-09     NaN     NaN     NaN     NaN       NaN        NaN
#
#    quantity  average  change %  volume total  ratio  ratio 1m  ratio 3m  \
# 0     261.0   1070.0       NaN      279270.0  0.077     0.085     0.085
# 1       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 2       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 3       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 4       NaN      NaN       NaN           NaN    NaN       NaN       NaN
#
#    ratio 6m  ratio 1y  ratio 2y  ratio 3y start_date
# 0     0.082      0.08      0.08      0.08 1997-01-09
# 1       NaN       NaN       NaN       NaN 2002-10-10
# 2       NaN       NaN       NaN       NaN 1999-04-15
# 3       NaN       NaN       NaN       NaN 1999-10-28
# 4       NaN       NaN       NaN       NaN 1997-05-15

# %%
print(df_clean.shape, df_new.shape, df.shape)
# Out:
# (189860, 20) (189860, 19) (43441, 19)

# %%
df_drop = df_clean[df_clean['date'] >= df_clean['start_date']]

# %%
min(df_drop.date[df_drop.stock_id == 'BESK'])
# Out:
# Timestamp('2002-10-10 00:00:00')

# %% [markdown]
# ### Filling NaN Values

# %%
df_sorted = df_drop.sort_values(by=['stock_id', 'date'], ascending=True)
test = df_sorted.drop_duplicates()
print(df_sorted.shape, test.shape)
# Out:
# (164754, 20) (164754, 20)

# %%
df_sorted.head()
# Out:
#    stock_id       date    open    high     low   close    volume  adj close  \
# 0       ALK 1997-01-09  1070.0  1070.0  1070.0  1070.0  279270.0     1070.0
# 22      ALK 1997-01-10     NaN     NaN     NaN     NaN       NaN        NaN
# 44      ALK 1997-01-11     NaN     NaN     NaN     NaN       NaN        NaN
# 66      ALK 1997-01-12     NaN     NaN     NaN     NaN       NaN        NaN
# 88      ALK 1997-01-13     NaN     NaN     NaN     NaN       NaN        NaN
#
#     quantity  average  change %  volume total  ratio  ratio 1m  ratio 3m  \
# 0      261.0   1070.0       NaN      279270.0  0.077     0.085     0.085
# 22       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 44       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 66       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 88       NaN      NaN       NaN           NaN    NaN       NaN       NaN
#
#     ratio 6m  ratio 1y  ratio 2y  ratio 3y start_date
# 0      0.082      0.08      0.08      0.08 1997-01-09
# 22       NaN       NaN       NaN       NaN 1997-01-09
# 44       NaN       NaN       NaN       NaN 1997-01-09
# 66       NaN       NaN       NaN       NaN 1997-01-09
# 88       NaN       NaN       NaN       NaN 1997-01-09

# %%
column_average = df_sorted['average']
df_sorted.drop('average', axis=1, inplace=True)
df_sorted.insert(5, 'average', column_average)

# %%
df_sorted
# Out:
#        stock_id       date    open    high     low  average   close    volume  \
# 0           ALK 1997-01-09  1070.0  1070.0  1070.0   1070.0  1070.0  279270.0
# 22          ALK 1997-01-10     NaN     NaN     NaN      NaN     NaN       NaN
# 44          ALK 1997-01-11     NaN     NaN     NaN      NaN     NaN       NaN
# 66          ALK 1997-01-12     NaN     NaN     NaN      NaN     NaN       NaN
# 88          ALK 1997-01-13     NaN     NaN     NaN      NaN     NaN       NaN
# ...         ...        ...     ...     ...     ...      ...     ...       ...
# 189771     VITA 2020-08-21     NaN     NaN     NaN      NaN     NaN       NaN
# 189793     VITA 2020-08-22     NaN     NaN     NaN      NaN     NaN       NaN
# 189815     VITA 2020-08-23     NaN     NaN     NaN      NaN     NaN       NaN
# 189837     VITA 2020-08-24     NaN     NaN     NaN      NaN     NaN       NaN
# 189859     VITA 2020-08-25     NaN     NaN     NaN      NaN     NaN       NaN
#
#         adj close  quantity  change %  volume total  ratio  ratio 1m  \
# 0          1070.0     261.0       NaN      279270.0  0.077     0.085
# 22            NaN       NaN       NaN           NaN    NaN       NaN
# 44            NaN       NaN       NaN           NaN    NaN       NaN
# 66            NaN       NaN       NaN           NaN    NaN       NaN
# 88            NaN       NaN       NaN           NaN    NaN       NaN
# ...           ...       ...       ...           ...    ...       ...
# 189771        NaN       NaN       NaN           NaN    NaN       NaN
# 189793        NaN       NaN       NaN           NaN    NaN       NaN
# 189815        NaN       NaN       NaN           NaN    NaN       NaN
# 189837        NaN       NaN       NaN           NaN    NaN       NaN
# 189859        NaN       NaN       NaN           NaN    NaN       NaN
#
#         ratio 3m  ratio 6m  ratio 1y  ratio 2y  ratio 3y start_date
# 0          0.085     0.082      0.08      0.08      0.08 1997-01-09
# 22           NaN       NaN       NaN       NaN       NaN 1997-01-09
# 44           NaN       NaN       NaN       NaN       NaN 1997-01-09
# 66           NaN       NaN       NaN       NaN       NaN 1997-01-09
# 88           NaN       NaN       NaN       NaN       NaN 1997-01-09
# ...          ...       ...       ...       ...       ...        ...
# 189771       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189793       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189815       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189837       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189859       NaN       NaN       NaN       NaN       NaN 1998-10-13
#
# [164754 rows x 20 columns]

# %%
# average will be equal to close price because there is no transactions on Nan 
# open, high, low are fulfil with close price because there is no transaction next day
df_sorted[['open', 'high', 'low', 'average', 
           'close']] = df_sorted[['open', 'high', 'low', 'average', 
                                  'close']].assign(close=df_sorted['close'].ffill()).bfill(axis=1)

# quantity, volume and volume total should be 0 also because of no transactions
df_sorted[['volume', 'quantity', 'volume total', 
           'change %']] = df_sorted[['volume', 'quantity', 'volume total', 'change %']].fillna(0)

# drop adj close same as close
df_sorted = df_sorted.drop('adj close', axis=1)

# %%
df_sorted = df_sorted[df_sorted.columns.drop(list(df_sorted.filter(regex='ratio')))]

# %%
df_sorted.head()
# Out:
#    stock_id       date    open    high     low  average   close    volume  \
# 0       ALK 1997-01-09  1070.0  1070.0  1070.0   1070.0  1070.0  279270.0
# 22      ALK 1997-01-10  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 44      ALK 1997-01-11  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 66      ALK 1997-01-12  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 88      ALK 1997-01-13  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
#
#     quantity  change %  volume total start_date
# 0      261.0       0.0      279270.0 1997-01-09
# 22       0.0       0.0           0.0 1997-01-09
# 44       0.0       0.0           0.0 1997-01-09
# 66       0.0       0.0           0.0 1997-01-09
# 88       0.0       0.0           0.0 1997-01-09

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x="date", y=np.log2(df_sorted.close), hue="stock_id", data=df_sorted)
plt.show()

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 10000, "display.max_columns", 10000): 
        display(df)

# %% [markdown]
# ## feature engineering

# %%
# dates - (year, month, day etc...)
# rolling - (QTY, volume, volumne total etc...) depend on target (1day, 7days, 30days up to 1 year)
# target closing price - (1day, 7days, 30days, 2months etc)
# target QTY - (1day, 7days, 30days, 2months etc)

# %%
df_final = df_sorted.copy()

# %% [markdown]
# ### Date Extraction

# %%
df_final['sale_year'] = df_final.date.dt.year
df_final['sale_month'] = df_final.date.dt.month
df_final['sale_week'] = df_final.date.dt.week
df_final['sale_day'] = df_final.date.dt.day
df_final['sale_dayofweek'] = df_final.date.dt.dayofweek
df_final['sale_dayofyear'] = df_final.date.dt.dayofyear
df_final['is_month_end'] = df_final.date.dt.is_month_end
df_final['is_month_start'] = df_final.date.dt.is_month_start
df_final['is_quarter_end'] = df_final.date.dt.is_quarter_end
df_final['is_quarter_start'] = df_final.date.dt.is_quarter_start
df_final['is_year_end'] = df_final.date.dt.is_year_end
df_final['is_year_start'] = df_final.date.dt.is_year_start
df_final['days_in_month'] = df_final.date.dt.days_in_month
df_final['is_leap_year'] = df_final.date.dt.is_leap_year
df_final['sales_elapsed'] = df_final.date - df_final.start_date
df_final['sales_elapsed'] = df_final.sales_elapsed.dt.days

# %%
display_all(df_final.tail(10).T)
# Out:
#                                189661               189683  \
# stock_id                         VITA                 VITA
# date              2020-08-16 00:00:00  2020-08-17 00:00:00
# open                            14080                14080
# high                            14080                14080
# low                             14080                14080
# average                         14080                14080
# close                           14080                14080
# volume                              0                    0
# quantity                            0                    0
# change %                            0                    0
# volume total                        0                    0
# start_date        1998-10-13 00:00:00  1998-10-13 00:00:00
# sale_year                        2020                 2020
# sale_month                          8                    8
# sale_week                          33                   34
# sale_day                           16                   17
# sale_dayofweek                      6                    0
# sale_dayofyear                    229                  230
# is_month_end                    False                False
# is_month_start                  False                False
# is_quarter_end                  False                False
# is_quarter_start                False                False
# is_year_end                     False                False
# is_year_start                   False                False
# days_in_month                      31                   31
# is_leap_year                     True                 True
# sales_elapsed                    7978                 7979
#
#                                189705               189727  \
# stock_id                         VITA                 VITA
# date              2020-08-18 00:00:00  2020-08-19 00:00:00
# open                            14080                14080
# high                            14080                14080
# low                             14080                14080
# average                         14080                14080
# close                           14080                14080
# volume                              0                    0
# quantity                            0                    0
# change %                            0                    0
# volume total                        0                    0
# start_date        1998-10-13 00:00:00  1998-10-13 00:00:00
# sale_year                        2020                 2020
# sale_month                          8                    8
# sale_week                          34                   34
# sale_day                           18                   19
# sale_dayofweek                      1                    2
# sale_dayofyear                    231                  232
# is_month_end                    False                False
# is_month_start                  False                False
# is_quarter_end                  False                False
# is_quarter_start                False                False
# is_year_end                     False                False
# is_year_start                   False                False
# days_in_month                      31                   31
# is_leap_year                     True                 True
# sales_elapsed                    7980                 7981
#
#                                189749               189771  \
# stock_id                         VITA                 VITA
# date              2020-08-20 00:00:00  2020-08-21 00:00:00
# open                            14080                14080
# high                            14080                14080
# low                             14080                14080
# average                         14080                14080
# close                           14080                14080
# volume                              0                    0
# quantity                            0                    0
# change %                            0                    0
# volume total                        0                    0
# start_date        1998-10-13 00:00:00  1998-10-13 00:00:00
# sale_year                        2020                 2020
# sale_month                          8                    8
# sale_week                          34                   34
# sale_day                           20                   21
# sale_dayofweek                      3                    4
# sale_dayofyear                    233                  234
# is_month_end                    False                False
# is_month_start                  False                False
# is_quarter_end                  False                False
# is_quarter_start                False                False
# is_year_end                     False                False
# is_year_start                   False                False
# days_in_month                      31                   31
# is_leap_year                     True                 True
# sales_elapsed                    7982                 7983
#
#                                189793               189815  \
# stock_id                         VITA                 VITA
# date              2020-08-22 00:00:00  2020-08-23 00:00:00
# open                            14080                14080
# high                            14080                14080
# low                             14080                14080
# average                         14080                14080
# close                           14080                14080
# volume                              0                    0
# quantity                            0                    0
# change %                            0                    0
# volume total                        0                    0
# start_date        1998-10-13 00:00:00  1998-10-13 00:00:00
# sale_year                        2020                 2020
# sale_month                          8                    8
# sale_week                          34                   34
# sale_day                           22                   23
# sale_dayofweek                      5                    6
# sale_dayofyear                    235                  236
# is_month_end                    False                False
# is_month_start                  False                False
# is_quarter_end                  False                False
# is_quarter_start                False                False
# is_year_end                     False                False
# is_year_start                   False                False
# days_in_month                      31                   31
# is_leap_year                     True                 True
# sales_elapsed                    7984                 7985
#
#                                189837               189859
# stock_id                         VITA                 VITA
# date              2020-08-24 00:00:00  2020-08-25 00:00:00
# open                            14080                14080
# high                            14080                14080
# low                             14080                14080
# average                         14080                14080
# close                           14080                14080
# volume                              0                    0
# quantity                            0                    0
# change %                            0                    0
# volume total                        0                    0
# start_date        1998-10-13 00:00:00  1998-10-13 00:00:00
# sale_year                        2020                 2020
# sale_month                          8                    8
# sale_week                          35                   35
# sale_day                           24                   25
# sale_dayofweek                      0                    1
# sale_dayofyear                    237                  238
# is_month_end                    False                False
# is_month_start                  False                False
# is_quarter_end                  False                False
# is_quarter_start                False                False
# is_year_end                     False                False
# is_year_start                   False                False
# days_in_month                      31                   31
# is_leap_year                     True                 True
# sales_elapsed                    7986                 7987

# %%
df_final = df_final.drop('start_date', axis=1)

# %%
plt.figure(figsize=(25, 8))
sns.boxenplot('stock_id', df_sorted.close, data=df_final)
plt.show()

# %% [markdown]
# ### rolling

# %%
df_final = df_final.set_index('date')

# %%
df_final.head(3)
# Out:
#            stock_id    open    high     low  average   close    volume  \
# date
# 1997-01-09      ALK  1070.0  1070.0  1070.0   1070.0  1070.0  279270.0
# 1997-01-10      ALK  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 1997-01-11      ALK  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
#
#             quantity  change %  volume total  ...  sale_dayofyear  \
# date                                          ...
# 1997-01-09     261.0       0.0      279270.0  ...               9
# 1997-01-10       0.0       0.0           0.0  ...              10
# 1997-01-11       0.0       0.0           0.0  ...              11
#
#             is_month_end  is_month_start  is_quarter_end  is_quarter_start  \
# date
# 1997-01-09         False           False           False             False
# 1997-01-10         False           False           False             False
# 1997-01-11         False           False           False             False
#
#             is_year_end  is_year_start  days_in_month  is_leap_year  \
# date
# 1997-01-09        False          False             31         False
# 1997-01-10        False          False             31         False
# 1997-01-11        False          False             31         False
#
#             sales_elapsed
# date
# 1997-01-09              0
# 1997-01-10              1
# 1997-01-11              2
#
# [3 rows x 25 columns]

# %%
#rolloing list for 30 days target
sum_7_qty_by_stock = []
sum_30_qty_by_stock = []
volumne_moving_avg_7 = []
volumne_moving_avg_30 = []
close_moving_avg_7 = []
close_moving_avg_30 = []
close_volatility_7 = []
close_volatility_30 = []
max_7_days = []
max_30_days = []
min_7_days = []
min_30_days = []
change_by_stock_daily_prev = []
profitability_daily_prev = []
ratio_prev = []

# %%
for stock in df_final.stock_id.unique():
    # sum quantity over last 7 days
    qty_sum_7 = df_final[df_final.stock_id == stock].quantity.rolling(7).sum()
    sum_7_qty_by_stock.append(qty_sum_7)
    # sum quantity over last 30 days
    qty_sum_30 = df_final[df_final.stock_id == stock].quantity.rolling(30).sum()
    sum_30_qty_by_stock.append(qty_sum_30)
    # moving average on volumne over last 7 days
    volumne_ma_7 = df_final[df_final.stock_id == stock].volume.rolling(7).mean()
    volumne_moving_avg_7.append(volumne_ma_7)
    # moving average on volumne over last 30 days
    volumne_ma_30 = df_final[df_final.stock_id == stock].volume.rolling(30).mean()
    volumne_moving_avg_30.append(volumne_ma_30)
    # moving average on close price over last 7 days
    close_ma_7 = df_final[df_final.stock_id == stock].close.rolling(7).mean()
    close_moving_avg_7.append(close_ma_7)
    # moving average on close price over last 30 days
    close_ma_30 = df_final[df_final.stock_id == stock].close.rolling(30).mean()
    close_moving_avg_30.append(close_ma_30)
    # volatility in close price over last 7 days
    close_volatility_7_by_stock = df_final[df_final.stock_id == stock].close.rolling(7).std().shift()
    close_volatility_7.append(close_volatility_7_by_stock)
    # volatility in close price over last 30 days
    close_volatility_30_by_stock = df_final[df_final.stock_id == stock].close.rolling(30).std().shift()
    close_volatility_30.append(close_volatility_30_by_stock)
    # max close price in last 7 days
    max_7_by_stock = df_final[df_final.stock_id == stock].close.rolling(7).max()
    max_7_days.append(max_7_by_stock)
    # max close price in last 30 days
    max_30_by_stock = df_final[df_final.stock_id == stock].close.rolling(30).max()
    max_30_days.append(max_30_by_stock)
    # min close price in last 7 days
    min_7_by_stock = df_final[df_final.stock_id == stock].close.rolling(7).min()
    min_7_days.append(min_7_by_stock)
    # min close price in last 30 days
    min_30_by_stock = df_final[df_final.stock_id == stock].close.rolling(30).min()
    min_30_days.append(min_30_by_stock)
    # ratio overall will be average price devided by max closing price over all time
    max_close_price = df_final[df_final.stock_id == stock].close.max()
    ratio_by_stock_prev = df_final[df_final.stock_id == stock].close.shift(1) / max_close_price
    ratio_prev.append(ratio_by_stock_prev)
    
    # daily_change new feature
    today = df_final[df_final.stock_id == stock].close.shift(1)
    yesterday = today.shift(2)
    change_by_stock =  today / yesterday - 1
    change_by_stock_daily_prev.append(change_by_stock)
    
    # daily_profitability_prev new feature
    profitability_by_stock_prev = df_final[df_final.stock_id == stock].close.shift(1) - df_final[df_final.stock_id == stock].open.shift(1)
    profitability_daily_prev.append(profitability_by_stock_prev)

# %%
chain_object_1 = itertools.chain.from_iterable(sum_7_qty_by_stock)
flattened_list_1 = list(chain_object_1)

chain_object_2 = itertools.chain.from_iterable(sum_30_qty_by_stock)
flattened_list_2 = list(chain_object_2)

chain_object_3 = itertools.chain.from_iterable(volumne_moving_avg_7)
flattened_list_3 = list(chain_object_3)

chain_object_4 = itertools.chain.from_iterable(volumne_moving_avg_30)
flattened_list_4 = list(chain_object_4)

chain_object_5 = itertools.chain.from_iterable(close_moving_avg_7)
flattened_list_5 = list(chain_object_5)

chain_object_6 = itertools.chain.from_iterable(close_moving_avg_30)
flattened_list_6 = list(chain_object_6)

chain_object_7 = itertools.chain.from_iterable(close_volatility_7)
flattened_list_7 = list(chain_object_7)

chain_object_8 = itertools.chain.from_iterable(close_volatility_30)
flattened_list_8 = list(chain_object_8)

chain_object_9 = itertools.chain.from_iterable(max_7_days)
flattened_list_9 = list(chain_object_9)

chain_object_10 = itertools.chain.from_iterable(max_30_days)
flattened_list_10 = list(chain_object_10)

chain_object_11 = itertools.chain.from_iterable(min_7_days)
flattened_list_11 = list(chain_object_11)

chain_object_12 = itertools.chain.from_iterable(min_30_days)
flattened_list_12 = list(chain_object_12)

ratio_object = itertools.chain.from_iterable(ratio_prev)
flattened_list_13 = list(ratio_object)

change_daily_object = itertools.chain.from_iterable(change_by_stock_daily_prev)
flattened_list_14 = list(change_daily_object)

profitability_object = itertools.chain.from_iterable(profitability_daily_prev)
flattened_list_15 = list(profitability_object)

# %%
rolling_7_days = pd.DataFrame({'sum_7_qty_by_stock':flattened_list_1,
                               'sum_30_qty_by_stock':flattened_list_2,
                               'moving_avg_volume_7_days':flattened_list_3,
                               'moving_avg_volume_30_days':flattened_list_4,
                               'moving_avg_close_7_days':flattened_list_5,
                               'moving_avg_close_30_days':flattened_list_6,
                               'volatility_7_days':flattened_list_7,
                               'volatility_30_days':flattened_list_8,
                               'max_7_days':flattened_list_9,
                               'max_30_days':flattened_list_10,
                               'min_7_days':flattened_list_11,
                               'min_30_days':flattened_list_12,
                               'ratio_overall_prev':flattened_list_13,
                               'change_daily_prev':flattened_list_14,
                               'profitability_daily_prev':flattened_list_15}
                             )

# %%
print(df_final.shape, rolling_7_days.shape)
# Out:
# (164754, 25) (164754, 15)

# %%
df_7_days = pd.concat([df_final.reset_index(), rolling_7_days], axis=1)

# %%
len(df_7_days.columns)
# Out:
# 41

# %%
ratio_7_days = []
ratio_30_days = []

# Calculating ratios up to 7 and 30 days
for stock in df_7_days.stock_id.unique():
    ratio_7 = df_7_days[df_7_days.stock_id == stock].average.shift(1) / df_7_days[df_7_days.stock_id == stock].max_7_days
    ratio_30 = df_7_days[df_7_days.stock_id == stock].average.shift(1) / df_7_days[df_7_days.stock_id == stock].max_30_days
    ratio_7_days.append(ratio_7)
    ratio_30_days.append(ratio_30)

# %%
chain_object_16 = itertools.chain.from_iterable(ratio_7_days)
flattened_list_16 = list(chain_object_16)

chain_object_17 = itertools.chain.from_iterable(ratio_30_days)
flattened_list_17 = list(chain_object_17)

ratios_df = pd.DataFrame({'ratio_7_days':flattened_list_16,
                          'ratio_30_days':flattened_list_17
                         }
                        )

# %%
df_7_days = pd.concat([df_7_days, ratios_df], axis=1)

# %%
len(df_7_days.columns)
# Out:
# 43

# %%
### Add column based on data analysis

# 1 day
df_7_days['prevopen_1'] = df_7_days.groupby(['stock_id'])['open'].shift(2)
#(open - prevopen) / prevopen
df_7_days['returnsOpenPrevRaw1'] = (df_7_days.open.shift(1) - df_7_days.prevopen_1) / df_7_days.prevopen_1

#10 days
df_7_days['prevopen_7'] = df_7_days.groupby(['stock_id'])['open'].shift(8)
df_7_days['returnsOpenPrevRaw_7'] = (df_7_days.open.shift(1) - df_7_days.prevopen_7) / df_7_days.prevopen_7

#Rate of change

# pct_chg = lambda x:x.pct_change()
# df_7_days['pct'] = df_7_days.groupby(['stock_id'])['close'].apply(pct_chg)

#Z-score
# zscore = lambda x:(x-x.mean())/x.std()
# df_7_days['z_score'] = df_7_days.groupby(['stock_id'])['close'].apply(zscore)

#percentile transformation
#rollrank = lambda x: x.rolling(200, min_periods=20).apply(lambda x:pd.Series(x).rank(pct=True)[0])
#df_7_days['percentile'] = df_7_days.groupby(['stock_id'])['volume'].apply(rollrank)

# %%
display_all(df_7_days.tail(25).T)
# Out:
#                                         164729               164730  \
# date                       2020-08-01 00:00:00  2020-08-02 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   31                   31
# sale_day                                     1                    2
# sale_dayofweek                               5                    6
# sale_dayofyear                             214                  215
# is_month_end                             False                False
# is_month_start                            True                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7963                 7964
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164731               164732  \
# date                       2020-08-03 00:00:00  2020-08-04 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   32                   32
# sale_day                                     3                    4
# sale_dayofweek                               0                    1
# sale_dayofyear                             216                  217
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7965                 7966
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164733               164734  \
# date                       2020-08-05 00:00:00  2020-08-06 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   32                   32
# sale_day                                     5                    6
# sale_dayofweek                               2                    3
# sale_dayofyear                             218                  219
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7967                 7968
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164735               164736  \
# date                       2020-08-07 00:00:00  2020-08-08 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   32                   32
# sale_day                                     7                    8
# sale_dayofweek                               4                    5
# sale_dayofyear                             220                  221
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7969                 7970
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164737               164738  \
# date                       2020-08-09 00:00:00  2020-08-10 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   32                   33
# sale_day                                     9                   10
# sale_dayofweek                               6                    0
# sale_dayofyear                             222                  223
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7971                 7972
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164739               164740  \
# date                       2020-08-11 00:00:00  2020-08-12 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   33                   33
# sale_day                                    11                   12
# sale_dayofweek                               1                    2
# sale_dayofyear                             224                  225
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7973                 7974
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164741               164742  \
# date                       2020-08-13 00:00:00  2020-08-14 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   33                   33
# sale_day                                    13                   14
# sale_dayofweek                               3                    4
# sale_dayofyear                             226                  227
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7975                 7976
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164743               164744  \
# date                       2020-08-15 00:00:00  2020-08-16 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   33                   33
# sale_day                                    15                   16
# sale_dayofweek                               5                    6
# sale_dayofyear                             228                  229
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7977                 7978
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164745               164746  \
# date                       2020-08-17 00:00:00  2020-08-18 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   34                   34
# sale_day                                    17                   18
# sale_dayofweek                               0                    1
# sale_dayofyear                             230                  231
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7979                 7980
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164747               164748  \
# date                       2020-08-19 00:00:00  2020-08-20 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   34                   34
# sale_day                                    19                   20
# sale_dayofweek                               2                    3
# sale_dayofyear                             232                  233
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7981                 7982
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164749               164750  \
# date                       2020-08-21 00:00:00  2020-08-22 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   34                   34
# sale_day                                    21                   22
# sale_dayofweek                               4                    5
# sale_dayofyear                             234                  235
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7983                 7984
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164751               164752  \
# date                       2020-08-23 00:00:00  2020-08-24 00:00:00
# stock_id                                  VITA                 VITA
# open                                     14080                14080
# high                                     14080                14080
# low                                      14080                14080
# average                                  14080                14080
# close                                    14080                14080
# volume                                       0                    0
# quantity                                     0                    0
# change %                                     0                    0
# volume total                                 0                    0
# sale_year                                 2020                 2020
# sale_month                                   8                    8
# sale_week                                   34                   35
# sale_day                                    23                   24
# sale_dayofweek                               6                    0
# sale_dayofyear                             236                  237
# is_month_end                             False                False
# is_month_start                           False                False
# is_quarter_end                           False                False
# is_quarter_start                         False                False
# is_year_end                              False                False
# is_year_start                            False                False
# days_in_month                               31                   31
# is_leap_year                              True                 True
# sales_elapsed                             7985                 7986
# sum_7_qty_by_stock                           0                    0
# sum_30_qty_by_stock                          0                    0
# moving_avg_volume_7_days                     0                    0
# moving_avg_volume_30_days                    0                    0
# moving_avg_close_7_days                  14080                14080
# moving_avg_close_30_days                 14080                14080
# volatility_7_days                    0.0005859            0.0005859
# volatility_30_days                  0.00072935           0.00072935
# max_7_days                               14080                14080
# max_30_days                              14080                14080
# min_7_days                               14080                14080
# min_30_days                              14080                14080
# ratio_overall_prev                      0.5632               0.5632
# change_daily_prev                            0                    0
# profitability_daily_prev                     0                    0
# ratio_7_days                                 1                    1
# ratio_30_days                                1                    1
# prevopen_1                               14080                14080
# returnsOpenPrevRaw1                          0                    0
# prevopen_7                               14080                14080
# returnsOpenPrevRaw_7                         0                    0
#
#                                         164753
# date                       2020-08-25 00:00:00
# stock_id                                  VITA
# open                                     14080
# high                                     14080
# low                                      14080
# average                                  14080
# close                                    14080
# volume                                       0
# quantity                                     0
# change %                                     0
# volume total                                 0
# sale_year                                 2020
# sale_month                                   8
# sale_week                                   35
# sale_day                                    25
# sale_dayofweek                               1
# sale_dayofyear                             238
# is_month_end                             False
# is_month_start                           False
# is_quarter_end                           False
# is_quarter_start                         False
# is_year_end                              False
# is_year_start                            False
# days_in_month                               31
# is_leap_year                              True
# sales_elapsed                             7987
# sum_7_qty_by_stock                           0
# sum_30_qty_by_stock                          0
# moving_avg_volume_7_days                     0
# moving_avg_volume_30_days                    0
# moving_avg_close_7_days                  14080
# moving_avg_close_30_days                 14080
# volatility_7_days                    0.0005859
# volatility_30_days                  0.00072935
# max_7_days                               14080
# max_30_days                              14080
# min_7_days                               14080
# min_30_days                              14080
# ratio_overall_prev                      0.5632
# change_daily_prev                            0
# profitability_daily_prev                     0
# ratio_7_days                                 1
# ratio_30_days                                1
# prevopen_1                               14080
# returnsOpenPrevRaw1                          0
# prevopen_7                               14080
# returnsOpenPrevRaw_7                         0

# %% [markdown]
# ### setting ALK dataset for training, validation and test

# %%
alk_df = df_7_days[df_7_days.stock_id == 'ALK']

# %%
to_drop = ['date', 'stock_id', 'open', 'high', 'low', 'average', 'volume', 'quantity', 'change %', 'volume total']

# %%
alk_df = alk_df.dropna()

# %%
alk_df.drop(to_drop, axis=1, inplace=True)

# %%
len(alk_df.columns)
# Out:
# 37

# %% [markdown]
# ### split dataset

# %%
X, y = alk_df.drop('close', axis=1), alk_df.close

# %%
scaler = StandardScaler()
normalizer = Normalizer()

# %%
def split_vals(dataset, n_test):
    n = dataset.shape[0] - n_test
    train_valid = dataset[:n].copy()
    return train_valid[:-n_test].copy(), train_valid[:n_test].copy(), dataset[-n_test:]

n_test = 30
X_train, X_valid, X_test = split_vals(X, n_test)
y_train, y_valid, y_test = split_vals(y, n_test)
X_train.shape, X_valid.shape, X_test.shape, y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((8540, 36), (30, 36), (30, 36), (8540,), (30,), (30,))

# %%
import math

def rmse(x,y):
    return math.sqrt(((x-y)**2).mean())

def print_score(model, X_train, y_train, X_valid, y_valid):
    res = [np.sqrt(mean_squared_error(model.predict(X_train), y_train)), 
           np.sqrt(mean_squared_error(model.predict(X_valid), y_valid)),
           model.score(X_train, y_train),
           model.score(X_valid, y_valid)]
    if hasattr(model, 'oob_score_'):
        res.append(model.oob_score_)
    print(res)

# %% [markdown]
# ### Fine-tune RandomForestRegressor

# %%
model = RandomForestRegressor(n_jobs=-1, n_estimators=40, min_samples_leaf=1, max_features=0.5, oob_score=True)
# %time model.fit(X_train, y_train)
print_score(model, X_train, y_train, X_valid, y_valid)
# Out:
# Wall time: 2.28 s
# [33.515196586396804, 87.14503296707927, 0.9998655717867965, 0.9698652429699628, 0.9990495251100021]

# %%
def rf_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'imp':m.feature_importances_}
                       ).sort_values('imp', ascending=False)

# %%
fi = rf_feat_importance(model, X_train)
fi[:10]
# Out:
#                         cols       imp
# 27        ratio_overall_prev  0.342499
# 19   moving_avg_close_7_days  0.241668
# 23                max_7_days  0.203734
# 25                min_7_days  0.135708
# 34                prevopen_7  0.033996
# 32                prevopen_1  0.022575
# 24               max_30_days  0.018442
# 26               min_30_days  0.000261
# 20  moving_avg_close_30_days  0.000244
# 14             sales_elapsed  0.000154

# %%
fi.plot('cols', 'imp', figsize=(12,4), legend=False);

# %%
def plot_fi(fi):
    return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)
plot_fi(fi[:30])

# %%
to_keep = fi[fi.imp>0.005].cols;
len(to_keep)
# Out:
# 7

# %%
df_keep = alk_df[to_keep].copy()
X_train_keep, X_valid_keep, X_test_keep = split_vals(df_keep, n_test)

# %%
model_keep = RandomForestRegressor(n_jobs=-1, n_estimators=40, min_samples_leaf=1, max_features=0.5, oob_score=True)
# %time model_keep.fit(X_train_keep, y_train)
print_score(model_keep, X_train_keep, y_train, X_valid_keep, y_valid)
# Out:
# Wall time: 743 ms
# [34.428824483138406, 119.24345202924921, 0.999858142836008, 0.9435776075512615, 0.9990446054804778]

# %%
from scipy.cluster import hierarchy as hc

corr = np.round(sp.stats.spearmanr(df_keep).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,10))
dendrogram = hc.dendrogram(z, labels=df_keep.columns, orientation='left', leaf_font_size=16)
plt.show()

# %%
def get_oob(df):
    m = RandomForestRegressor(n_jobs=-1, n_estimators=40, min_samples_leaf=1, max_features=0.5, oob_score=True)
    x, _, _ = split_vals(df, n_test)
    m.fit(x, y_train)
    return m.oob_score_

# %%
get_oob(df_keep)
# Out:
# 0.9990505091224519

# %%
for c in ('prevopen_1', 'moving_avg_close_7_days'):
    print(c, get_oob(df_keep.drop(c, axis=1)))
# Out:
# prevopen_1 0.99905123139483
# moving_avg_close_7_days 0.9990736246172893

# %% [markdown]
# ### extrapolation

# %%
df_ext = df_keep.copy()
df_ext['is_valid'] = 1
df_ext.is_valid[:n_test] = 0
# Out:
# C:\Users\Gj\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X_ext, y_ext = df_ext.drop('is_valid', axis=1), df_ext.is_valid

# %%
X_train_ext, X_valid_ext, X_test_ext = split_vals(X_ext, n_test)
y_train_ext, y_valid_ext, y_test_ext = split_vals(y_ext, n_test)

# %%
model_ext = RandomForestRegressor(n_jobs=-1, n_estimators=40, min_samples_leaf=1, max_features=0.5, oob_score=True)
# %time model_ext.fit(X_train_ext, y_train_ext)
model_ext.oob_score_
# Out:
# Wall time: 431 ms
# 0.8934811856713245

# %%
fi = rf_feat_importance(model_ext, X_train_ext); fi[:10]
# Out:
#                       cols       imp
# 6              max_30_days  0.611557
# 1  moving_avg_close_7_days  0.104318
# 4               prevopen_7  0.079291
# 0       ratio_overall_prev  0.062301
# 3               min_7_days  0.061469
# 2               max_7_days  0.047050
# 5               prevopen_1  0.034014

# %%
feats=['max_30_days']
(X_train_ext[feats]/1000).describe()
# Out:
#        max_30_days
# count  8540.000000
# mean      4.595211
# std       3.031534
# min       0.800000
# 25%       1.960000
# 50%       4.301000
# 75%       5.600000
# max      14.150000

# %%
X_train_ext.columns
# Out:
# Index(['ratio_overall_prev', 'moving_avg_close_7_days', 'max_7_days',
#        'min_7_days', 'prevopen_7', 'prevopen_1', 'max_30_days'],
#       dtype='object')

# %%
X_train_ext.drop(feats, axis=1, inplace=True)
m_drop = RandomForestRegressor(n_jobs=-1, n_estimators=40, min_samples_leaf=1, max_features=0.5, oob_score=True)
m_drop.fit(X_train_ext, y_train_ext);
m_drop.oob_score_
# Out:
# 0.32046218308474583

# %%
for f in feats:
    df_subs = df_keep.drop(f, axis=1)
    X_train_sub, X_valid_sub, X_test_sub = split_vals(df_subs, n_test)
    m = RandomForestRegressor(n_jobs=-1, n_estimators=40, min_samples_leaf=1, max_features=0.5, oob_score=True)
    m.fit(X_train_sub, y_train_ext)
    print(f)
    print_score(m, X_train_sub, y_train_ext, X_valid_sub, y_valid_ext)
# Out:
# max_30_days
# [0.044507184807425305, 0.7389856667087179, 0.4341189164886642, 0.0, 0.3536044258464325]

# %% [markdown]
# ### final model

# %%
X, y = alk_df.drop('close', axis=1), alk_df.close

# %%
X_train, X_valid, X_test = split_vals(X, n_test)
y_train, y_valid, y_test = split_vals(y, n_test)
X_train.shape, X_valid.shape, X_test.shape, y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((8540, 36), (30, 36), (30, 36), (8540,), (30,), (30,))

# %%
model_final = RandomForestRegressor(n_jobs=-1, n_estimators=40, min_samples_leaf=1, max_features=0.5, oob_score=True)
# %time model_final.fit(X_train, y_train)
print_score(model_final, X_train, y_train, X_valid, y_valid)
# Out:
# Wall time: 2.33 s
# [33.13350104561564, 105.8615251165408, 0.9998686162844067, 0.9555308621046176, 0.9990844949350794]

# %%
x_ax = range(len(y_valid))
plt.plot(x_ax, y_valid, label="original")
plt.plot(x_ax, model_final.predict(X_valid), label="predicted")
plt.title("stock price and predicted price")
plt.legend()
plt.show()

# %%
ranfor_pred = model_final.predict(X_test)

# %%
plt.figure(figsize=(10,5))

plt.scatter(y_test, ranfor_pred, color='red')
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', lw=2)
plt.title('Ground Truth vs Predicted - RF')
plt.xlabel(xlabel='Actual')
plt.ylabel(ylabel='Predicted')
plt.show()

# %% [markdown]
# ### qty forecast

# %%
alk_df_qty = df_7_days[df_7_days.stock_id == 'ALK']
alk_df_qty = alk_df_qty.dropna()
to_drop_qty = ['date', 'stock_id', 'open', 'high', 'low', 'average', 'volume', 'close', 'change %', 'volume total']
alk_df_qty.drop(to_drop_qty, axis=1, inplace=True)

# %%
X_qty, y_qty = alk_df_qty.drop('quantity', axis=1), alk_df_qty.quantity

# %%
X_train_qty, X_valid_qty, X_test_qty = split_vals(X_qty, n_test)
y_train_qty, y_valid_qty, y_test_qty = split_vals(y_qty, n_test)
X_train_qty.shape, X_valid_qty.shape, X_test_qty.shape, y_train_qty.shape, y_valid_qty.shape, y_test_qty.shape
# Out:
# ((8540, 36), (30, 36), (30, 36), (8540,), (30,), (30,))

# %%
# %%time

parametars = {
    'n_estimators': [30, 50, 100, 150, 200, 300, 400, 500],
    'min_samples_leaf': [1, 3, 5, 10, 25]
}

model_qty = RandomForestRegressor(n_jobs=-1, max_features=0.5)
clf = GridSearchCV(model_qty, parametars)
clf.fit(X_train, y_train)

print(f'Best params: {clf.best_params_}')
print(f'Best score = {clf.best_score_}')
# Out:
# Best params: {'min_samples_leaf': 1, 'n_estimators': 100}
# Best score = 0.9778831346920935
# Wall time: 24min 44s

# %%
model_qty = RandomForestRegressor(n_jobs=-1, n_estimators=300, min_samples_leaf=1, max_features=0.5, oob_score=True)
# %time model_qty.fit(X_train_qty, y_train_qty)
print_score(model_qty, X_train_qty, y_train_qty, X_valid_qty, y_valid_qty)
# Out:
# Wall time: 16.6 s
# [168.6602945701545, 58.938770353144804, 0.9082299477125789, 0.8223910504707388, 0.30806467049097597]

# %%
x_ax = range(len(y_valid_qty))
plt.plot(x_ax, y_valid_qty, label="original")
plt.plot(x_ax, model_qty.predict(X_valid_qty), label="predicted")
plt.title("stock price and predicted price")
plt.legend()
plt.show()

# %%
ranfor_pred_qty = model_qty.predict(X_test_qty)

# %%
plt.figure(figsize=(10,5))

plt.scatter(y_test_qty, ranfor_pred_qty, color='red')
plt.plot([y_train_qty.min(), y_train_qty.max()], [y_train_qty.min(), y_train_qty.max()], 'k--', lw=2)
plt.title('Ground Truth vs Predicted - RF')
plt.xlabel(xlabel='Actual')
plt.ylabel(ylabel='Predicted')
plt.show()

# %% [markdown]
# ### XGBOOST

# %%
xgb_reg = xgb.XGBRegressor(colsample_bylevel=0.7, colsample_bynode=0.7, colsample_bytree=0.7, 
                           learning_rate=0.05, n_estimators=400, 
                           gamma=0.02, max_depth=15)

# %%
xgb_reg.fit(X_train, y_train)
print_score(xgb_reg, X_train, y_train, X_valid, y_valid)
# Out:
# [0.2617808377143273, 0.12877213986782174, 0.999999991798702, 0.9999999341999471]

# %%
x_ax = range(len(y_valid))
plt.plot(x_ax, y_valid, label="original")
plt.plot(x_ax, xgb_reg.predict(X_valid), label="predicted")
plt.title("stock price and predicted price")
plt.legend()
plt.show()

# %%
xgb_price = xgb_reg.predict(X_test)

# %%
plt.figure(figsize=(10,5))

plt.scatter(y_test, xgb_price, color='red')
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', lw=2)
plt.title('Ground Truth vs Predicted - XGB')
plt.xlabel(xlabel='Actual')
plt.ylabel(ylabel='Predicted')
plt.show()

# %%
xgb_reg_qty = xgb.XGBRegressor(colsample_bylevel=0.7, colsample_bynode=0.7, colsample_bytree=0.7, 
                           learning_rate=0.05, n_estimators=400, 
                           gamma=0.02, max_depth=15)

# %%
xgb_reg_qty.fit(X_train_qty, y_train_qty)
print_score(xgb_reg_qty, X_train_qty, y_train_qty, X_valid_qty, y_valid_qty)
# Out:
# [1.7842664572636078, 0.6436239134251373, 0.9999897294265566, 0.9999788199467718]

# %%
x_ax = range(len(y_valid_qty))
plt.plot(x_ax, y_valid_qty, label="original")
plt.plot(x_ax, xgb_reg_qty.predict(X_valid_qty), label="predicted")
plt.title("stock price and predicted price")
plt.legend()
plt.show()

# %%
xgb_qty = xgb_reg_qty.predict(X_test_qty)

# %%
plt.figure(figsize=(10,5))

plt.scatter(y_test_qty, xgb_qty, color='red')
plt.plot([y_train_qty.min(), y_train_qty.max()], [y_train_qty.min(), y_train_qty.max()], 'k--', lw=2)
plt.title('Ground Truth vs Predicted - XGB')
plt.xlabel(xlabel='Actual')
plt.ylabel(ylabel='Predicted')
plt.show()
