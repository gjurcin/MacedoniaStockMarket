# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import math
import itertools
import xgboost as xgb
import regex as re

from keras.models import Sequential
from keras.layers import Dense, LSTM, SimpleRNN, Activation
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from keras.callbacks import ModelCheckpoint, EarlyStopping
from xgboost import plot_importance, plot_tree
from sklearn.model_selection import train_test_split, GridSearchCV

# %matplotlib inline

# Chart drawing
import plotly as py
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %% [markdown]
# # Loading Dataset

# %%
stock_exchange_mk = pd.read_csv('data_mse_mse_historic_data_active.csv', sep='\t', parse_dates=['Date'])

# %%
df = pd.DataFrame(stock_exchange_mk)
df["stock_id"] = df["stock_id"].astype('category')
df.columns = df.columns.str.lower()

# %% [markdown]
# # Missing Dates

# %%
stocks = df.stock_id.unique()
dates_all = pd.period_range(min(df.date), max(df.date)).to_timestamp()
idx = pd.MultiIndex.from_product((dates_all, stocks), names=['date', 'stock_id'])
df_new = df.set_index(['date', 'stock_id']).reindex(idx).reset_index()

# %% [markdown]
# ### Drop Unnecessary Dates

# %%
df_list = []
for stock in df.stock_id.unique():
    each_df = df[df.stock_id == stock]
    groupby_stock = each_df.groupby([pd.PeriodIndex(data=each_df.date, freq='D'), 'stock_id'])
    df_list.append(groupby_stock)

# %%
stock_name = []
stock_start_date = []
for i in df_list:
    name = min(i.date)[0][1]
    stock_name.append(name)
    date = min(i.date)[0][0]
    stock_start_date.append(date)
    
start_date = dict(zip(stock_name, stock_start_date))

# %%
start_date_df = pd.DataFrame.from_dict(start_date, orient='index', dtype='datetime64[ns]', columns=['start_date'])

# %%
start_date_df.head()
# Out:
#      start_date
# ALK  1997-01-09
# BESK 2002-10-10
# FERS 1999-04-15
# GRNT 1999-10-28
# KMB  1997-05-15

# %%
df_clean = df_new.set_index('stock_id').join(start_date_df, lsuffix='_filter', on='stock_id').reset_index()

# %%
df_clean.head()
# Out:
#   stock_id       date    open    high     low   close    volume  adj close  \
# 0      ALK 1997-01-09  1070.0  1070.0  1070.0  1070.0  279270.0     1070.0
# 1     BESK 1997-01-09     NaN     NaN     NaN     NaN       NaN        NaN
# 2     FERS 1997-01-09     NaN     NaN     NaN     NaN       NaN        NaN
# 3     GRNT 1997-01-09     NaN     NaN     NaN     NaN       NaN        NaN
# 4      KMB 1997-01-09     NaN     NaN     NaN     NaN       NaN        NaN
#
#    quantity  average  change %  volume total  ratio  ratio 1m  ratio 3m  \
# 0     261.0   1070.0       NaN      279270.0  0.077     0.085     0.085
# 1       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 2       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 3       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 4       NaN      NaN       NaN           NaN    NaN       NaN       NaN
#
#    ratio 6m  ratio 1y  ratio 2y  ratio 3y start_date
# 0     0.082      0.08      0.08      0.08 1997-01-09
# 1       NaN       NaN       NaN       NaN 2002-10-10
# 2       NaN       NaN       NaN       NaN 1999-04-15
# 3       NaN       NaN       NaN       NaN 1999-10-28
# 4       NaN       NaN       NaN       NaN 1997-05-15

# %%
print(df_clean.shape, df_new.shape, df.shape)
# Out:
# (189860, 20) (189860, 19) (43441, 19)

# %%
df_drop = df_clean[df_clean['date'] >= df_clean['start_date']]

# %%
min(df_drop.date[df_drop.stock_id == 'BESK'])
# Out:
# Timestamp('2002-10-10 00:00:00')

# %% [markdown]
# ### Filling NaN Values

# %%
df_sorted = df_drop.sort_values(by=['stock_id', 'date'], ascending=True)
test = df_sorted.drop_duplicates()
print(df_sorted.shape, test.shape)
# Out:
# (164754, 20) (164754, 20)

# %%
df_sorted.head()
# Out:
#    stock_id       date    open    high     low   close    volume  adj close  \
# 0       ALK 1997-01-09  1070.0  1070.0  1070.0  1070.0  279270.0     1070.0
# 22      ALK 1997-01-10     NaN     NaN     NaN     NaN       NaN        NaN
# 44      ALK 1997-01-11     NaN     NaN     NaN     NaN       NaN        NaN
# 66      ALK 1997-01-12     NaN     NaN     NaN     NaN       NaN        NaN
# 88      ALK 1997-01-13     NaN     NaN     NaN     NaN       NaN        NaN
#
#     quantity  average  change %  volume total  ratio  ratio 1m  ratio 3m  \
# 0      261.0   1070.0       NaN      279270.0  0.077     0.085     0.085
# 22       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 44       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 66       NaN      NaN       NaN           NaN    NaN       NaN       NaN
# 88       NaN      NaN       NaN           NaN    NaN       NaN       NaN
#
#     ratio 6m  ratio 1y  ratio 2y  ratio 3y start_date
# 0      0.082      0.08      0.08      0.08 1997-01-09
# 22       NaN       NaN       NaN       NaN 1997-01-09
# 44       NaN       NaN       NaN       NaN 1997-01-09
# 66       NaN       NaN       NaN       NaN 1997-01-09
# 88       NaN       NaN       NaN       NaN 1997-01-09

# %%
column_average = df_sorted['average']
df_sorted.drop('average', axis=1, inplace=True)
df_sorted.insert(5, 'average', column_average)

# %%
df_sorted
# Out:
#        stock_id       date    open    high     low  average   close    volume  \
# 0           ALK 1997-01-09  1070.0  1070.0  1070.0  1070.00  1070.0  279270.0
# 22          ALK 1997-01-10     NaN     NaN     NaN      NaN     NaN       NaN
# 44          ALK 1997-01-11     NaN     NaN     NaN      NaN     NaN       NaN
# 66          ALK 1997-01-12     NaN     NaN     NaN      NaN     NaN       NaN
# 88          ALK 1997-01-13     NaN     NaN     NaN      NaN     NaN       NaN
# 110         ALK 1997-01-14  1070.0  1070.0  1050.0  1059.86  1050.0  378370.0
# 132         ALK 1997-01-15     NaN     NaN     NaN      NaN     NaN       NaN
# 154         ALK 1997-01-16  1050.0  1030.0  1030.0  1030.00  1030.0  246170.0
# 176         ALK 1997-01-17     NaN     NaN     NaN      NaN     NaN       NaN
# 198         ALK 1997-01-18     NaN     NaN     NaN      NaN     NaN       NaN
# 220         ALK 1997-01-19     NaN     NaN     NaN      NaN     NaN       NaN
# 242         ALK 1997-01-20     NaN     NaN     NaN      NaN     NaN       NaN
# 264         ALK 1997-01-21  1030.0  1030.0  1010.0  1026.39  1010.0   62610.0
# 286         ALK 1997-01-22     NaN     NaN     NaN      NaN     NaN       NaN
# 308         ALK 1997-01-23  1010.0  1010.0  1009.0  1009.83  1010.0  421100.0
# 330         ALK 1997-01-24     NaN     NaN     NaN      NaN     NaN       NaN
# 352         ALK 1997-01-25     NaN     NaN     NaN      NaN     NaN       NaN
# 374         ALK 1997-01-26     NaN     NaN     NaN      NaN     NaN       NaN
# 396         ALK 1997-01-27     NaN     NaN     NaN      NaN     NaN       NaN
# 418         ALK 1997-01-28  1010.0  1009.0  1000.0  1000.00  1000.0  290630.0
# 440         ALK 1997-01-29     NaN     NaN     NaN      NaN     NaN       NaN
# 462         ALK 1997-01-30  1000.0  1000.0  1000.0  1000.00  1000.0  393000.0
# 484         ALK 1997-01-31     NaN     NaN     NaN      NaN     NaN       NaN
# 506         ALK 1997-02-01     NaN     NaN     NaN      NaN     NaN       NaN
# 528         ALK 1997-02-02     NaN     NaN     NaN      NaN     NaN       NaN
# 550         ALK 1997-02-03     NaN     NaN     NaN      NaN     NaN       NaN
# 572         ALK 1997-02-04  1000.0  1000.0  1000.0  1000.00  1000.0  779000.0
# 594         ALK 1997-02-05     NaN     NaN     NaN      NaN     NaN       NaN
# 616         ALK 1997-02-06  1000.0  1000.0  1000.0  1000.00  1000.0  396000.0
# 638         ALK 1997-02-07     NaN     NaN     NaN      NaN     NaN       NaN
# ...         ...        ...     ...     ...     ...      ...     ...       ...
# 189221     VITA 2020-07-27     NaN     NaN     NaN      NaN     NaN       NaN
# 189243     VITA 2020-07-28     NaN     NaN     NaN      NaN     NaN       NaN
# 189265     VITA 2020-07-29     NaN     NaN     NaN      NaN     NaN       NaN
# 189287     VITA 2020-07-30     NaN     NaN     NaN      NaN     NaN       NaN
# 189309     VITA 2020-07-31     NaN     NaN     NaN      NaN     NaN       NaN
# 189331     VITA 2020-08-01     NaN     NaN     NaN      NaN     NaN       NaN
# 189353     VITA 2020-08-02     NaN     NaN     NaN      NaN     NaN       NaN
# 189375     VITA 2020-08-03     NaN     NaN     NaN      NaN     NaN       NaN
# 189397     VITA 2020-08-04     NaN     NaN     NaN      NaN     NaN       NaN
# 189419     VITA 2020-08-05     NaN     NaN     NaN      NaN     NaN       NaN
# 189441     VITA 2020-08-06     NaN     NaN     NaN      NaN     NaN       NaN
# 189463     VITA 2020-08-07     NaN     NaN     NaN      NaN     NaN       NaN
# 189485     VITA 2020-08-08     NaN     NaN     NaN      NaN     NaN       NaN
# 189507     VITA 2020-08-09     NaN     NaN     NaN      NaN     NaN       NaN
# 189529     VITA 2020-08-10     NaN     NaN     NaN      NaN     NaN       NaN
# 189551     VITA 2020-08-11     NaN     NaN     NaN      NaN     NaN       NaN
# 189573     VITA 2020-08-12     NaN     NaN     NaN      NaN     NaN       NaN
# 189595     VITA 2020-08-13     NaN     NaN     NaN      NaN     NaN       NaN
# 189617     VITA 2020-08-14     NaN     NaN     NaN      NaN     NaN       NaN
# 189639     VITA 2020-08-15     NaN     NaN     NaN      NaN     NaN       NaN
# 189661     VITA 2020-08-16     NaN     NaN     NaN      NaN     NaN       NaN
# 189683     VITA 2020-08-17     NaN     NaN     NaN      NaN     NaN       NaN
# 189705     VITA 2020-08-18     NaN     NaN     NaN      NaN     NaN       NaN
# 189727     VITA 2020-08-19     NaN     NaN     NaN      NaN     NaN       NaN
# 189749     VITA 2020-08-20     NaN     NaN     NaN      NaN     NaN       NaN
# 189771     VITA 2020-08-21     NaN     NaN     NaN      NaN     NaN       NaN
# 189793     VITA 2020-08-22     NaN     NaN     NaN      NaN     NaN       NaN
# 189815     VITA 2020-08-23     NaN     NaN     NaN      NaN     NaN       NaN
# 189837     VITA 2020-08-24     NaN     NaN     NaN      NaN     NaN       NaN
# 189859     VITA 2020-08-25     NaN     NaN     NaN      NaN     NaN       NaN
#
#         adj close  quantity  change %  volume total  ratio  ratio 1m  \
# 0          1070.0     261.0       NaN      279270.0  0.077     0.085
# 22            NaN       NaN       NaN           NaN    NaN       NaN
# 44            NaN       NaN       NaN           NaN    NaN       NaN
# 66            NaN       NaN       NaN           NaN    NaN       NaN
# 88            NaN       NaN       NaN           NaN    NaN       NaN
# 110        1050.0     357.0       1.0      378370.0  0.076     0.084
# 132           NaN       NaN       NaN           NaN    NaN       NaN
# 154        1030.0     239.0       3.0      246170.0  0.074     0.082
# 176           NaN       NaN       NaN           NaN    NaN       NaN
# 198           NaN       NaN       NaN           NaN    NaN       NaN
# 220           NaN       NaN       NaN           NaN    NaN       NaN
# 242           NaN       NaN       NaN           NaN    NaN       NaN
# 264        1010.0      61.0       0.0       62610.0  0.074     0.082
# 286           NaN       NaN       NaN           NaN    NaN       NaN
# 308        1010.0     417.0       2.0      421100.0  0.073     0.080
# 330           NaN       NaN       NaN           NaN    NaN       NaN
# 352           NaN       NaN       NaN           NaN    NaN       NaN
# 374           NaN       NaN       NaN           NaN    NaN       NaN
# 396           NaN       NaN       NaN           NaN    NaN       NaN
# 418        1000.0     290.0       1.0      290630.0  0.072     0.080
# 440           NaN       NaN       NaN           NaN    NaN       NaN
# 462        1000.0     393.0       0.0      393000.0  0.072     0.080
# 484           NaN       NaN       NaN           NaN    NaN       NaN
# 506           NaN       NaN       NaN           NaN    NaN       NaN
# 528           NaN       NaN       NaN           NaN    NaN       NaN
# 550           NaN       NaN       NaN           NaN    NaN       NaN
# 572        1000.0     779.0       0.0      779000.0  0.072     0.080
# 594           NaN       NaN       NaN           NaN    NaN       NaN
# 616        1000.0     396.0       0.0      396000.0  0.072     0.080
# 638           NaN       NaN       NaN           NaN    NaN       NaN
# ...           ...       ...       ...           ...    ...       ...
# 189221        NaN       NaN       NaN           NaN    NaN       NaN
# 189243        NaN       NaN       NaN           NaN    NaN       NaN
# 189265        NaN       NaN       NaN           NaN    NaN       NaN
# 189287        NaN       NaN       NaN           NaN    NaN       NaN
# 189309        NaN       NaN       NaN           NaN    NaN       NaN
# 189331        NaN       NaN       NaN           NaN    NaN       NaN
# 189353        NaN       NaN       NaN           NaN    NaN       NaN
# 189375        NaN       NaN       NaN           NaN    NaN       NaN
# 189397        NaN       NaN       NaN           NaN    NaN       NaN
# 189419        NaN       NaN       NaN           NaN    NaN       NaN
# 189441        NaN       NaN       NaN           NaN    NaN       NaN
# 189463        NaN       NaN       NaN           NaN    NaN       NaN
# 189485        NaN       NaN       NaN           NaN    NaN       NaN
# 189507        NaN       NaN       NaN           NaN    NaN       NaN
# 189529        NaN       NaN       NaN           NaN    NaN       NaN
# 189551        NaN       NaN       NaN           NaN    NaN       NaN
# 189573        NaN       NaN       NaN           NaN    NaN       NaN
# 189595        NaN       NaN       NaN           NaN    NaN       NaN
# 189617        NaN       NaN       NaN           NaN    NaN       NaN
# 189639        NaN       NaN       NaN           NaN    NaN       NaN
# 189661        NaN       NaN       NaN           NaN    NaN       NaN
# 189683        NaN       NaN       NaN           NaN    NaN       NaN
# 189705        NaN       NaN       NaN           NaN    NaN       NaN
# 189727        NaN       NaN       NaN           NaN    NaN       NaN
# 189749        NaN       NaN       NaN           NaN    NaN       NaN
# 189771        NaN       NaN       NaN           NaN    NaN       NaN
# 189793        NaN       NaN       NaN           NaN    NaN       NaN
# 189815        NaN       NaN       NaN           NaN    NaN       NaN
# 189837        NaN       NaN       NaN           NaN    NaN       NaN
# 189859        NaN       NaN       NaN           NaN    NaN       NaN
#
#         ratio 3m  ratio 6m  ratio 1y  ratio 2y  ratio 3y start_date
# 0          0.085     0.082     0.080     0.080     0.080 1997-01-09
# 22           NaN       NaN       NaN       NaN       NaN 1997-01-09
# 44           NaN       NaN       NaN       NaN       NaN 1997-01-09
# 66           NaN       NaN       NaN       NaN       NaN 1997-01-09
# 88           NaN       NaN       NaN       NaN       NaN 1997-01-09
# 110        0.084     0.081     0.080     0.080     0.080 1997-01-09
# 132          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 154        0.082     0.079     0.077     0.077     0.077 1997-01-09
# 176          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 198          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 220          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 242          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 264        0.082     0.079     0.077     0.077     0.077 1997-01-09
# 286          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 308        0.080     0.078     0.076     0.076     0.076 1997-01-09
# 330          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 352          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 374          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 396          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 418        0.080     0.077     0.075     0.075     0.075 1997-01-09
# 440          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 462        0.080     0.077     0.075     0.075     0.075 1997-01-09
# 484          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 506          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 528          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 550          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 572        0.080     0.077     0.075     0.075     0.075 1997-01-09
# 594          NaN       NaN       NaN       NaN       NaN 1997-01-09
# 616        0.080     0.077     0.075     0.075     0.075 1997-01-09
# 638          NaN       NaN       NaN       NaN       NaN 1997-01-09
# ...          ...       ...       ...       ...       ...        ...
# 189221       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189243       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189265       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189287       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189309       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189331       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189353       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189375       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189397       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189419       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189441       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189463       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189485       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189507       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189529       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189551       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189573       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189595       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189617       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189639       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189661       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189683       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189705       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189727       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189749       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189771       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189793       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189815       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189837       NaN       NaN       NaN       NaN       NaN 1998-10-13
# 189859       NaN       NaN       NaN       NaN       NaN 1998-10-13
#
# [164754 rows x 20 columns]

# %%
# average will be equal to close price because there is no transactions on Nan 
# open, high, low are fulfil with close price because there is no transaction next day
df_sorted[['open', 'high', 'low', 'average', 
           'close']] = df_sorted[['open', 'high', 'low', 'average', 
                                  'close']].assign(close=df_sorted['close'].ffill()).bfill(axis=1)

# quantity, volume and volume total should be 0 also because of no transactions
df_sorted[['volume', 'quantity', 'volume total', 
           'change %']] = df_sorted[['volume', 'quantity', 'volume total', 'change %']].fillna(0)

# drop adj close same as close
df_sorted = df_sorted.drop('adj close', axis=1)

# %%
df_sorted = df_sorted[df_sorted.columns.drop(list(df_sorted.filter(regex='ratio')))]

# %%
df_sorted.head()
# Out:
#    stock_id       date    open    high     low  average   close    volume  \
# 0       ALK 1997-01-09  1070.0  1070.0  1070.0   1070.0  1070.0  279270.0
# 22      ALK 1997-01-10  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 44      ALK 1997-01-11  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 66      ALK 1997-01-12  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 88      ALK 1997-01-13  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
#
#     quantity  change %  volume total start_date
# 0      261.0       0.0      279270.0 1997-01-09
# 22       0.0       0.0           0.0 1997-01-09
# 44       0.0       0.0           0.0 1997-01-09
# 66       0.0       0.0           0.0 1997-01-09
# 88       0.0       0.0           0.0 1997-01-09

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x="date", y=np.log2(df_sorted.close), hue="stock_id", data=df_sorted)
plt.show()

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 10000, "display.max_columns", 10000): 
        display(df)

# %% [markdown]
# ## feature engineering

# %%
# dates - (year, month, day etc...)
# rolling - (QTY, volume, volumne total etc...) depend on target (1day, 7days, 30days up to 1 year)
# target closing price - (1day, 7days, 30days, 2months etc)
# target QTY - (1day, 7days, 30days, 2months etc)

# %%
df_final = df_sorted.copy()

# %% [markdown]
# ### Date Extraction

# %%
df_final['sale_year'] = df_final.date.dt.year
df_final['sale_month'] = df_final.date.dt.month
df_final['sale_week'] = df_final.date.dt.week
df_final['sale_day'] = df_final.date.dt.day
df_final['sale_dayofweek'] = df_final.date.dt.dayofweek
df_final['sale_dayofyear'] = df_final.date.dt.dayofyear
df_final['is_month_end'] = df_final.date.dt.is_month_end
df_final['is_month_start'] = df_final.date.dt.is_month_start
df_final['is_quarter_end'] = df_final.date.dt.is_quarter_end
df_final['is_quarter_start'] = df_final.date.dt.is_quarter_start
df_final['is_year_end'] = df_final.date.dt.is_year_end
df_final['is_year_start'] = df_final.date.dt.is_year_start
df_final['days_in_month'] = df_final.date.dt.days_in_month
df_final['is_leap_year'] = df_final.date.dt.is_leap_year
df_final['sales_elapsed'] = df_final.date - df_final.start_date
df_final['sales_elapsed'] = df_final.sales_elapsed.dt.days

# %%
display_all(df_final.tail(10).T)
# Out:
#                                189661               189683  \
# stock_id                         VITA                 VITA
# date              2020-08-16 00:00:00  2020-08-17 00:00:00
# open                            14080                14080
# high                            14080                14080
# low                             14080                14080
# average                         14080                14080
# close                           14080                14080
# volume                              0                    0
# quantity                            0                    0
# change %                            0                    0
# volume total                        0                    0
# start_date        1998-10-13 00:00:00  1998-10-13 00:00:00
# sale_year                        2020                 2020
# sale_month                          8                    8
# sale_week                          33                   34
# sale_day                           16                   17
# sale_dayofweek                      6                    0
# sale_dayofyear                    229                  230
# is_month_end                    False                False
# is_month_start                  False                False
# is_quarter_end                  False                False
# is_quarter_start                False                False
# is_year_end                     False                False
# is_year_start                   False                False
# days_in_month                      31                   31
# is_leap_year                     True                 True
# sales_elapsed                    7978                 7979
#
#                                189705               189727  \
# stock_id                         VITA                 VITA
# date              2020-08-18 00:00:00  2020-08-19 00:00:00
# open                            14080                14080
# high                            14080                14080
# low                             14080                14080
# average                         14080                14080
# close                           14080                14080
# volume                              0                    0
# quantity                            0                    0
# change %                            0                    0
# volume total                        0                    0
# start_date        1998-10-13 00:00:00  1998-10-13 00:00:00
# sale_year                        2020                 2020
# sale_month                          8                    8
# sale_week                          34                   34
# sale_day                           18                   19
# sale_dayofweek                      1                    2
# sale_dayofyear                    231                  232
# is_month_end                    False                False
# is_month_start                  False                False
# is_quarter_end                  False                False
# is_quarter_start                False                False
# is_year_end                     False                False
# is_year_start                   False                False
# days_in_month                      31                   31
# is_leap_year                     True                 True
# sales_elapsed                    7980                 7981
#
#                                189749               189771  \
# stock_id                         VITA                 VITA
# date              2020-08-20 00:00:00  2020-08-21 00:00:00
# open                            14080                14080
# high                            14080                14080
# low                             14080                14080
# average                         14080                14080
# close                           14080                14080
# volume                              0                    0
# quantity                            0                    0
# change %                            0                    0
# volume total                        0                    0
# start_date        1998-10-13 00:00:00  1998-10-13 00:00:00
# sale_year                        2020                 2020
# sale_month                          8                    8
# sale_week                          34                   34
# sale_day                           20                   21
# sale_dayofweek                      3                    4
# sale_dayofyear                    233                  234
# is_month_end                    False                False
# is_month_start                  False                False
# is_quarter_end                  False                False
# is_quarter_start                False                False
# is_year_end                     False                False
# is_year_start                   False                False
# days_in_month                      31                   31
# is_leap_year                     True                 True
# sales_elapsed                    7982                 7983
#
#                                189793               189815  \
# stock_id                         VITA                 VITA
# date              2020-08-22 00:00:00  2020-08-23 00:00:00
# open                            14080                14080
# high                            14080                14080
# low                             14080                14080
# average                         14080                14080
# close                           14080                14080
# volume                              0                    0
# quantity                            0                    0
# change %                            0                    0
# volume total                        0                    0
# start_date        1998-10-13 00:00:00  1998-10-13 00:00:00
# sale_year                        2020                 2020
# sale_month                          8                    8
# sale_week                          34                   34
# sale_day                           22                   23
# sale_dayofweek                      5                    6
# sale_dayofyear                    235                  236
# is_month_end                    False                False
# is_month_start                  False                False
# is_quarter_end                  False                False
# is_quarter_start                False                False
# is_year_end                     False                False
# is_year_start                   False                False
# days_in_month                      31                   31
# is_leap_year                     True                 True
# sales_elapsed                    7984                 7985
#
#                                189837               189859
# stock_id                         VITA                 VITA
# date              2020-08-24 00:00:00  2020-08-25 00:00:00
# open                            14080                14080
# high                            14080                14080
# low                             14080                14080
# average                         14080                14080
# close                           14080                14080
# volume                              0                    0
# quantity                            0                    0
# change %                            0                    0
# volume total                        0                    0
# start_date        1998-10-13 00:00:00  1998-10-13 00:00:00
# sale_year                        2020                 2020
# sale_month                          8                    8
# sale_week                          35                   35
# sale_day                           24                   25
# sale_dayofweek                      0                    1
# sale_dayofyear                    237                  238
# is_month_end                    False                False
# is_month_start                  False                False
# is_quarter_end                  False                False
# is_quarter_start                False                False
# is_year_end                     False                False
# is_year_start                   False                False
# days_in_month                      31                   31
# is_leap_year                     True                 True
# sales_elapsed                    7986                 7987

# %%
df_final = df_final.drop('start_date', axis=1)

# %%
plt.figure(figsize=(25, 8))
sns.boxenplot('stock_id', df_sorted.close, data=df_final)
plt.show()

# %% [markdown]
# ### rolling

# %%
#df_final = df_final.set_index('date')

# %%
df_final.head(3)
# Out:
#    stock_id       date    open    high     low  average   close    volume  \
# 0       ALK 1997-01-09  1070.0  1070.0  1070.0   1070.0  1070.0  279270.0
# 22      ALK 1997-01-10  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 44      ALK 1997-01-11  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
#
#     quantity  change %  ...  sale_dayofyear  is_month_end  is_month_start  \
# 0      261.0       0.0  ...               9         False           False
# 22       0.0       0.0  ...              10         False           False
# 44       0.0       0.0  ...              11         False           False
#
#     is_quarter_end  is_quarter_start  is_year_end  is_year_start  \
# 0            False             False        False          False
# 22           False             False        False          False
# 44           False             False        False          False
#
#     days_in_month  is_leap_year  sales_elapsed
# 0              31         False              0
# 22             31         False              1
# 44             31         False              2
#
# [3 rows x 26 columns]

# %%
#rolloing for 7 days target
sum_7_qty_by_stock = []
volumne_moving_avg_7 = []
close_moving_avg_7 = []
close_volatility_7 = []
max_7_days = []
min_7_days = []
change_by_stock_daily = []
profitability_daily = []
ratio = []

for stock in df_final.stock_id.unique():
    # sum quantity over last 7 days
    qty_sum = df_final[df_final.stock_id == stock].quantity.rolling(7).sum()
    sum_7_qty_by_stock.append(qty_sum)
    # moving average on volumne over last 7 days
    volumne_ma_7 = df_final[df_final.stock_id == stock].volume.rolling(7).mean()
    volumne_moving_avg_7.append(volumne_ma_7)
    # moving average on close price over last 7 days
    close_ma_7 = df_final[df_final.stock_id == stock].close.rolling(7).mean()
    close_moving_avg_7.append(close_ma_7)
    # volatility in close price over last 7 days
    close_volatility_7_by_stock = df_final[df_final.stock_id == stock].close.rolling(7).std().shift()
    close_volatility_7.append(close_volatility_7_by_stock)
    # max close price in last 7 days
    max_7_by_stock = df_final[df_final.stock_id == stock].close.rolling(7).max()
    max_7_days.append(max_7_by_stock)
    # min close price in last 7 days
    min_7_by_stock = df_final[df_final.stock_id == stock].close.rolling(7).min()
    min_7_days.append(min_7_by_stock)
    # ratio overall will be average price devided by max closing price over all time
    max_close_price = df_final[df_final.stock_id == stock].close.max()
    ratio_by_stock = df_final[df_final.stock_id == stock].close / max_close_price
    ratio.append(ratio_by_stock)
    
    # daily_change new feature
    today = df_final[df_final.stock_id == stock].close
    yesterday = today.shift()
    change_by_stock =  today / yesterday - 1
    change_by_stock_daily.append(change_by_stock)
    
    # daily_profitability new feature
    profitability_by_stock = df_final[df_final.stock_id == stock].close - df_final[df_final.stock_id == stock].open
    profitability_daily.append(profitability_by_stock)

# %%
chain_object_1 = itertools.chain.from_iterable(sum_7_qty_by_stock)
flattened_list_1 = list(chain_object_1)

chain_object_2 = itertools.chain.from_iterable(volumne_moving_avg_7)
flattened_list_2 = list(chain_object_2)

chain_object_3 = itertools.chain.from_iterable(close_moving_avg_7)
flattened_list_3 = list(chain_object_3)

chain_object_4 = itertools.chain.from_iterable(close_volatility_7)
flattened_list_4 = list(chain_object_4)

chain_object_5 = itertools.chain.from_iterable(max_7_days)
flattened_list_5 = list(chain_object_5)

chain_object_6 = itertools.chain.from_iterable(min_7_days)
flattened_list_6 = list(chain_object_6)

ratio_object = itertools.chain.from_iterable(ratio)
flattened_list_7 = list(ratio_object)

change_daily_object = itertools.chain.from_iterable(change_by_stock_daily)
flattened_list_8 = list(change_daily_object)

profitability_object = itertools.chain.from_iterable(profitability_daily)
flattened_list_9 = list(profitability_object)

# %%
rolling_7_days = pd.DataFrame({'sum_7_qty_by_stock':flattened_list_1, 
                               'moving_avg_volume_7_days':flattened_list_2,
                               'moving_avg_close_7_days':flattened_list_3,
                               'volatility_7_days':flattened_list_4,
                               'max_7_days':flattened_list_5,
                               'min_7_days':flattened_list_6,
                               'ratio_overall':flattened_list_7,
                               'change_daily':flattened_list_8,
                               'profitability_daily':flattened_list_9}
                             )

# %%
print(df_final.shape, rolling_7_days.shape)
# Out:
# (164754, 26) (164754, 9)

# %%
df_7_days = pd.concat([df_final.reset_index(), rolling_7_days], axis=1)

# %%
# Calculating ratios up to 7 days
df_7_days['ratio_7_days'] = df_7_days.average / df_7_days.max_7_days

# %%
display_all(df_7_days.head(10).T)
# Out:
#                                             0                    1  \
# index                                       0                   22
# stock_id                                  ALK                  ALK
# date                      1997-01-09 00:00:00  1997-01-10 00:00:00
# open                                     1070                 1070
# high                                     1070                 1070
# low                                      1070                 1070
# average                                  1070                 1070
# close                                    1070                 1070
# volume                                 279270                    0
# quantity                                  261                    0
# change %                                    0                    0
# volume total                           279270                    0
# sale_year                                1997                 1997
# sale_month                                  1                    1
# sale_week                                   2                    2
# sale_day                                    9                   10
# sale_dayofweek                              3                    4
# sale_dayofyear                              9                   10
# is_month_end                            False                False
# is_month_start                          False                False
# is_quarter_end                          False                False
# is_quarter_start                        False                False
# is_year_end                             False                False
# is_year_start                           False                False
# days_in_month                              31                   31
# is_leap_year                            False                False
# sales_elapsed                               0                    1
# sum_7_qty_by_stock                        NaN                  NaN
# moving_avg_volume_7_days                  NaN                  NaN
# moving_avg_close_7_days                   NaN                  NaN
# volatility_7_days                         NaN                  NaN
# max_7_days                                NaN                  NaN
# min_7_days                                NaN                  NaN
# ratio_overall                       0.0756184            0.0756184
# change_daily                              NaN                    0
# profitability_daily                         0                    0
# ratio_7_days                              NaN                  NaN
#
#                                             2                    3  \
# index                                      44                   66
# stock_id                                  ALK                  ALK
# date                      1997-01-11 00:00:00  1997-01-12 00:00:00
# open                                     1070                 1070
# high                                     1070                 1070
# low                                      1070                 1070
# average                                  1070                 1070
# close                                    1070                 1070
# volume                                      0                    0
# quantity                                    0                    0
# change %                                    0                    0
# volume total                                0                    0
# sale_year                                1997                 1997
# sale_month                                  1                    1
# sale_week                                   2                    2
# sale_day                                   11                   12
# sale_dayofweek                              5                    6
# sale_dayofyear                             11                   12
# is_month_end                            False                False
# is_month_start                          False                False
# is_quarter_end                          False                False
# is_quarter_start                        False                False
# is_year_end                             False                False
# is_year_start                           False                False
# days_in_month                              31                   31
# is_leap_year                            False                False
# sales_elapsed                               2                    3
# sum_7_qty_by_stock                        NaN                  NaN
# moving_avg_volume_7_days                  NaN                  NaN
# moving_avg_close_7_days                   NaN                  NaN
# volatility_7_days                         NaN                  NaN
# max_7_days                                NaN                  NaN
# min_7_days                                NaN                  NaN
# ratio_overall                       0.0756184            0.0756184
# change_daily                                0                    0
# profitability_daily                         0                    0
# ratio_7_days                              NaN                  NaN
#
#                                             4                    5  \
# index                                      88                  110
# stock_id                                  ALK                  ALK
# date                      1997-01-13 00:00:00  1997-01-14 00:00:00
# open                                     1070                 1070
# high                                     1070                 1070
# low                                      1070                 1050
# average                                  1070              1059.86
# close                                    1070                 1050
# volume                                      0               378370
# quantity                                    0                  357
# change %                                    0                    1
# volume total                                0               378370
# sale_year                                1997                 1997
# sale_month                                  1                    1
# sale_week                                   3                    3
# sale_day                                   13                   14
# sale_dayofweek                              0                    1
# sale_dayofyear                             13                   14
# is_month_end                            False                False
# is_month_start                          False                False
# is_quarter_end                          False                False
# is_quarter_start                        False                False
# is_year_end                             False                False
# is_year_start                           False                False
# days_in_month                              31                   31
# is_leap_year                            False                False
# sales_elapsed                               4                    5
# sum_7_qty_by_stock                        NaN                  NaN
# moving_avg_volume_7_days                  NaN                  NaN
# moving_avg_close_7_days                   NaN                  NaN
# volatility_7_days                         NaN                  NaN
# max_7_days                                NaN                  NaN
# min_7_days                                NaN                  NaN
# ratio_overall                       0.0756184            0.0742049
# change_daily                                0           -0.0186916
# profitability_daily                         0                  -20
# ratio_7_days                              NaN                  NaN
#
#                                             6                    7  \
# index                                     132                  154
# stock_id                                  ALK                  ALK
# date                      1997-01-15 00:00:00  1997-01-16 00:00:00
# open                                     1050                 1050
# high                                     1050                 1030
# low                                      1050                 1030
# average                                  1050                 1030
# close                                    1050                 1030
# volume                                      0               246170
# quantity                                    0                  239
# change %                                    0                    3
# volume total                                0               246170
# sale_year                                1997                 1997
# sale_month                                  1                    1
# sale_week                                   3                    3
# sale_day                                   15                   16
# sale_dayofweek                              2                    3
# sale_dayofyear                             15                   16
# is_month_end                            False                False
# is_month_start                          False                False
# is_quarter_end                          False                False
# is_quarter_start                        False                False
# is_year_end                             False                False
# is_year_start                           False                False
# days_in_month                              31                   31
# is_leap_year                            False                False
# sales_elapsed                               6                    7
# sum_7_qty_by_stock                        618                  596
# moving_avg_volume_7_days              93948.6                89220
# moving_avg_close_7_days               1064.29              1058.57
# volatility_7_days                         NaN                9.759
# max_7_days                               1070                 1070
# min_7_days                               1050                 1030
# ratio_overall                       0.0742049            0.0727915
# change_daily                                0           -0.0190476
# profitability_daily                         0                  -20
# ratio_7_days                         0.981308             0.962617
#
#                                             8                    9
# index                                     176                  198
# stock_id                                  ALK                  ALK
# date                      1997-01-17 00:00:00  1997-01-18 00:00:00
# open                                     1030                 1030
# high                                     1030                 1030
# low                                      1030                 1030
# average                                  1030                 1030
# close                                    1030                 1030
# volume                                      0                    0
# quantity                                    0                    0
# change %                                    0                    0
# volume total                                0                    0
# sale_year                                1997                 1997
# sale_month                                  1                    1
# sale_week                                   3                    3
# sale_day                                   17                   18
# sale_dayofweek                              4                    5
# sale_dayofyear                             17                   18
# is_month_end                            False                False
# is_month_start                          False                False
# is_quarter_end                          False                False
# is_quarter_start                        False                False
# is_year_end                             False                False
# is_year_start                           False                False
# days_in_month                              31                   31
# is_leap_year                            False                False
# sales_elapsed                               8                    9
# sum_7_qty_by_stock                        596                  596
# moving_avg_volume_7_days                89220                89220
# moving_avg_close_7_days               1052.86              1047.14
# volatility_7_days                     15.7359              17.9947
# max_7_days                               1070                 1070
# min_7_days                               1030                 1030
# ratio_overall                       0.0727915            0.0727915
# change_daily                                0                    0
# profitability_daily                         0                    0
# ratio_7_days                         0.962617             0.962617

# %%
### Add column based on data analysis

# 1 day
df_final['prevopen'] = df_final.groupby(['stock_id'])['open'].shift(1)
#(open - prevopen) / prevopen
df_final['returnsOpenPrevRaw1'] = (df_final.open - df_final.prevopen) / df_final.prevopen

#10 days
df_final['prevopen10'] = df_final.groupby(['stock_id'])['open'].shift(10)
df_final['returnsOpenPrevRaw10'] = (df_final.open - df_final.prevopen10) / df_final.prevopen10

#Volume diff
#It's often more important to know how a value is changing than to know the value itself.
df_final['volumeDiff'] = df_final.groupby(['stock_id'])['volume'].diff() #change since prior day
df_final['volumeDiff10'] = df_final.groupby(['stock_id'])['volume'].diff(50) #change since 10 days prior

#Rate of change
pct_chg = lambda x:x.pct_change()
df_final['pct'] = df_final.groupby(['stock_id'])['close'].apply(pct_chg)

#Z-score
zscore = lambda x:(x-x.mean())/x.std()
df_final['z_score'] = df_final.groupby(['stock_id'])['close'].apply(zscore)

#percentile transformation
rollrank = lambda x:x.rolling(200, min_periods=20).apply(lambda x:pd.Series(x).rank(pct=True)[0])
df_final['percentile'] = df_final.groupby(['stock_id'])['volume'].apply(rollrank)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: FutureWarning:
#
# Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning

# %%
df_final[df_final.stock_id == 'ALK'].close / df_final[df_final.stock_id == 'ALK'].close.max()
# Out:
# 0         0.075618
# 22        0.075618
# 44        0.075618
# 66        0.075618
# 88        0.075618
# 110       0.074205
# 132       0.074205
# 154       0.072792
# 176       0.072792
# 198       0.072792
# 220       0.072792
# 242       0.072792
# 264       0.071378
# 286       0.071378
# 308       0.071378
# 330       0.071378
# 352       0.071378
# 374       0.071378
# 396       0.071378
# 418       0.070671
# 440       0.070671
# 462       0.070671
# 484       0.070671
# 506       0.070671
# 528       0.070671
# 550       0.070671
# 572       0.070671
# 594       0.070671
# 616       0.070671
# 638       0.070671
#             ...
# 189200    0.901060
# 189222    0.871378
# 189244    0.890459
# 189266    0.897527
# 189288    0.883392
# 189310    0.883392
# 189332    0.883392
# 189354    0.883392
# 189376    0.876325
# 189398    0.872792
# 189420    0.862191
# 189442    0.876325
# 189464    0.876325
# 189486    0.876325
# 189508    0.872792
# 189530    0.883392
# 189552    0.883392
# 189574    0.883392
# 189596    0.883392
# 189618    0.883392
# 189640    0.883392
# 189662    0.876254
# 189684    0.869258
# 189706    0.869258
# 189728    0.863816
# 189750    0.868551
# 189772    0.868551
# 189794    0.868551
# 189816    0.868551
# 189838    0.862191
# Name: close, Length: 8630, dtype: float64

# %%
df_alk = df_final[df_final['stock_id'] == 'ALK']

# %%
df_alk.head()
# Out:
#    stock_id       date    open    high     low  average   close    volume  \
# 0       ALK 1997-01-09  1070.0  1070.0  1070.0   1070.0  1070.0  279270.0
# 22      ALK 1997-01-10  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 44      ALK 1997-01-11  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 66      ALK 1997-01-12  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
# 88      ALK 1997-01-13  1070.0  1070.0  1070.0   1070.0  1070.0       0.0
#
#     quantity  change %  ...  sale_dayofyear  is_month_end  is_month_start  \
# 0      261.0       0.0  ...               9         False           False
# 22       0.0       0.0  ...              10         False           False
# 44       0.0       0.0  ...              11         False           False
# 66       0.0       0.0  ...              12         False           False
# 88       0.0       0.0  ...              13         False           False
#
#     is_quarter_end  is_quarter_start  is_year_end  is_year_start  \
# 0            False             False        False          False
# 22           False             False        False          False
# 44           False             False        False          False
# 66           False             False        False          False
# 88           False             False        False          False
#
#     days_in_month  is_leap_year  sales_elapsed
# 0              31         False              0
# 22             31         False              1
# 44             31         False              2
# 66             31         False              3
# 88             31         False              4
#
# [5 rows x 26 columns]

# %%
df_alk.reset_index(inplace=True)

# %%
df_alk.head()
# Out:
#    index stock_id       date    open    high     low  average   close  \
# 0      0      ALK 1997-01-09  1070.0  1070.0  1070.0   1070.0  1070.0
# 1     22      ALK 1997-01-10  1070.0  1070.0  1070.0   1070.0  1070.0
# 2     44      ALK 1997-01-11  1070.0  1070.0  1070.0   1070.0  1070.0
# 3     66      ALK 1997-01-12  1070.0  1070.0  1070.0   1070.0  1070.0
# 4     88      ALK 1997-01-13  1070.0  1070.0  1070.0   1070.0  1070.0
#
#      volume  quantity  ...  sale_dayofyear  is_month_end  is_month_start  \
# 0  279270.0     261.0  ...               9         False           False
# 1       0.0       0.0  ...              10         False           False
# 2       0.0       0.0  ...              11         False           False
# 3       0.0       0.0  ...              12         False           False
# 4       0.0       0.0  ...              13         False           False
#
#    is_quarter_end  is_quarter_start  is_year_end  is_year_start  \
# 0           False             False        False          False
# 1           False             False        False          False
# 2           False             False        False          False
# 3           False             False        False          False
# 4           False             False        False          False
#
#    days_in_month  is_leap_year  sales_elapsed
# 0             31         False              0
# 1             31         False              1
# 2             31         False              2
# 3             31         False              3
# 4             31         False              4
#
# [5 rows x 27 columns]

# %%
test_size  = 0.15
valid_size = 0.15

test_split_idx  = int(df_alk.shape[0] * (1-test_size))
valid_split_idx = int(df_alk.shape[0] * (1-(valid_size+test_size)))

train_df  = df_alk.loc[:valid_split_idx].copy()
valid_df  = df_alk.loc[valid_split_idx+1:test_split_idx].copy()
test_df   = df_alk.loc[test_split_idx+1:].copy()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=train_df.date, y=train_df.close, name='Training'))
fig.add_trace(go.Scatter(x=valid_df.date, y=valid_df.close, name='Validation'))
fig.add_trace(go.Scatter(x=test_df.date,  y=test_df.close,  name='Test'))
fig.show()
# Out:
# <div>
#
#
#             <div id="02c386bd-ab00-4d00-acd5-a80cb9709804" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02c386bd-ab00-4d00-acd5-a80cb9709804")) {
#                     Plotly.newPlot(
#                         '02c386bd-ab00-4d00-acd5-a80cb9709804',
#                         [{"name": "Training", "type": "scatter", "x": ["1997-01-09T00:00:00", "1997-01-10T00:00:00", "1997-01-11T00:00:00", "1997-01-12T00:00:00", "1997-01-13T00:00:00", "1997-01-14T00:00:00", "1997-01-15T00:00:00", "1997-01-16T00:00:00", "1997-01-17T00:00:00", "1997-01-18T00:00:00", "1997-01-19T00:00:00", "1997-01-20T00:00:00", "1997-01-21T00:00:00", "1997-01-22T00:00:00", "1997-01-23T00:00:00", "1997-01-24T00:00:00", "1997-01-25T00:00:00", "1997-01-26T00:00:00", "1997-01-27T00:00:00", "1997-01-28T00:00:00", "1997-01-29T00:00:00", "1997-01-30T00:00:00", "1997-01-31T00:00:00", "1997-02-01T00:00:00", "1997-02-02T00:00:00", "1997-02-03T00:00:00", "1997-02-04T00:00:00", "1997-02-05T00:00:00", "1997-02-06T00:00:00", "1997-02-07T00:00:00", "1997-02-08T00:00:00", "1997-02-09T00:00:00", "1997-02-10T00:00:00", "1997-02-11T00:00:00", "1997-02-12T00:00:00", "1997-02-13T00:00:00", "1997-02-14T00:00:00", "1997-02-15T00:00:00", "1997-02-16T00:00:00", "1997-02-17T00:00:00", "1997-02-18T00:00:00", "1997-02-19T00:00:00", "1997-02-20T00:00:00", "1997-02-21T00:00:00", "1997-02-22T00:00:00", "1997-02-23T00:00:00", "1997-02-24T00:00:00", "1997-02-25T00:00:00", "1997-02-26T00:00:00", "1997-02-27T00:00:00", "1997-02-28T00:00:00", "1997-03-01T00:00:00", "1997-03-02T00:00:00", "1997-03-03T00:00:00", "1997-03-04T00:00:00", "1997-03-05T00:00:00", "1997-03-06T00:00:00", "1997-03-07T00:00:00", "1997-03-08T00:00:00", "1997-03-09T00:00:00", "1997-03-10T00:00:00", "1997-03-11T00:00:00", "1997-03-12T00:00:00", "1997-03-13T00:00:00", "1997-03-14T00:00:00", "1997-03-15T00:00:00", "1997-03-16T00:00:00", "1997-03-17T00:00:00", "1997-03-18T00:00:00", "1997-03-19T00:00:00", "1997-03-20T00:00:00", "1997-03-21T00:00:00", "1997-03-22T00:00:00", "1997-03-23T00:00:00", "1997-03-24T00:00:00", "1997-03-25T00:00:00", "1997-03-26T00:00:00", "1997-03-27T00:00:00", "1997-03-28T00:00:00", "1997-03-29T00:00:00", "1997-03-30T00:00:00", "1997-03-31T00:00:00", "1997-04-01T00:00:00", "1997-04-02T00:00:00", "1997-04-03T00:00:00", "1997-04-04T00:00:00", "1997-04-05T00:00:00", "1997-04-06T00:00:00", "1997-04-07T00:00:00", "1997-04-08T00:00:00", "1997-04-09T00:00:00", "1997-04-10T00:00:00", "1997-04-11T00:00:00", "1997-04-12T00:00:00", "1997-04-13T00:00:00", "1997-04-14T00:00:00", "1997-04-15T00:00:00", "1997-04-16T00:00:00", "1997-04-17T00:00:00", "1997-04-18T00:00:00", "1997-04-19T00:00:00", "1997-04-20T00:00:00", "1997-04-21T00:00:00", "1997-04-22T00:00:00", "1997-04-23T00:00:00", "1997-04-24T00:00:00", "1997-04-25T00:00:00", "1997-04-26T00:00:00", "1997-04-27T00:00:00", "1997-04-28T00:00:00", "1997-04-29T00:00:00", "1997-04-30T00:00:00", "1997-05-01T00:00:00", "1997-05-02T00:00:00", "1997-05-03T00:00:00", "1997-05-04T00:00:00", "1997-05-05T00:00:00", "1997-05-06T00:00:00", "1997-05-07T00:00:00", "1997-05-08T00:00:00", "1997-05-09T00:00:00", "1997-05-10T00:00:00", "1997-05-11T00:00:00", "1997-05-12T00:00:00", "1997-05-13T00:00:00", "1997-05-14T00:00:00", "1997-05-15T00:00:00", "1997-05-16T00:00:00", "1997-05-17T00:00:00", "1997-05-18T00:00:00", "1997-05-19T00:00:00", "1997-05-20T00:00:00", "1997-05-21T00:00:00", "1997-05-22T00:00:00", "1997-05-23T00:00:00", "1997-05-24T00:00:00", "1997-05-25T00:00:00", "1997-05-26T00:00:00", "1997-05-27T00:00:00", "1997-05-28T00:00:00", "1997-05-29T00:00:00", "1997-05-30T00:00:00", "1997-05-31T00:00:00", "1997-06-01T00:00:00", "1997-06-02T00:00:00", "1997-06-03T00:00:00", "1997-06-04T00:00:00", "1997-06-05T00:00:00", "1997-06-06T00:00:00", "1997-06-07T00:00:00", "1997-06-08T00:00:00", "1997-06-09T00:00:00", "1997-06-10T00:00:00", "1997-06-11T00:00:00", "1997-06-12T00:00:00", "1997-06-13T00:00:00", "1997-06-14T00:00:00", "1997-06-15T00:00:00", "1997-06-16T00:00:00", "1997-06-17T00:00:00", "1997-06-18T00:00:00", "1997-06-19T00:00:00", "1997-06-20T00:00:00", "1997-06-21T00:00:00", "1997-06-22T00:00:00", "1997-06-23T00:00:00", "1997-06-24T00:00:00", "1997-06-25T00:00:00", "1997-06-26T00:00:00", "1997-06-27T00:00:00", "1997-06-28T00:00:0 ...

# %% [markdown]
# #### Drop unnecessary columns

# %%
drop_cols = ['date', 'stock_id', 'open', 'low', 'high']

train_df = train_df.drop(drop_cols, 1)
valid_df = valid_df.drop(drop_cols, 1)
test_df  = test_df.drop(drop_cols, 1)

# %% [markdown]
# #### Split into features and labels

# %%
y_train = train_df['close'].copy()
X_train = train_df.drop(['close'], 1)

y_valid = valid_df['close'].copy()
X_valid = valid_df.drop(['close'], 1)

y_test  = test_df['close'].copy()
X_test  = test_df.drop(['close'], 1)

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6042 entries, 0 to 6041
# Data columns (total 21 columns):
# index               6042 non-null int64
# average             6042 non-null float64
# volume              6042 non-null float64
# quantity            6042 non-null float64
# change %            6042 non-null float64
# volume total        6042 non-null float64
# sale_year           6042 non-null int64
# sale_month          6042 non-null int64
# sale_week           6042 non-null int64
# sale_day            6042 non-null int64
# sale_dayofweek      6042 non-null int64
# sale_dayofyear      6042 non-null int64
# is_month_end        6042 non-null bool
# is_month_start      6042 non-null bool
# is_quarter_end      6042 non-null bool
# is_quarter_start    6042 non-null bool
# is_year_end         6042 non-null bool
# is_year_start       6042 non-null bool
# days_in_month       6042 non-null int64
# is_leap_year        6042 non-null bool
# sales_elapsed       6042 non-null int64
# dtypes: bool(7), float64(5), int64(9)
# memory usage: 702.2 KB

# %% [markdown]
# #### Fine-tune XGBoostRegressor

# %%
# %%time

parameters = {
    'n_estimators': [100, 200, 300, 400],
    'learning_rate': [0.001, 0.005, 0.01, 0.05],
    'max_depth': [8, 10, 12, 15],
    'gamma': [0.001, 0.005, 0.01, 0.02],
    'random_state': [42]
}

eval_set = [(X_train, y_train), (X_valid, y_valid)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror', verbose=False)
clf = GridSearchCV(model, parameters)

clf.fit(X_train, y_train)

print(f'Best params: {clf.best_params_}')
print(f'Best validation score = {clf.best_score_}')
# Out:
# Best params: {'gamma': 0.001, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 300, 'random_state': 42}
# Best validation score = 0.7453907326695688
# Wall time: 56min 36s

# %%
# %%time

model = xgb.XGBRegressor(**clf.best_params_, objective='reg:squarederror')
model.fit(X_train, y_train, eval_set=eval_set, verbose=False)
# Out:
# Wall time: 3.86 s
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0.001, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.05, max_delta_step=0, max_depth=8,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=0, num_parallel_tree=1, random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method=None, validate_parameters=False, verbosity=None)

# %%
plot_importance(model)

# %% [markdown]
# #### Calculate and visualize predictions

# %%
y_pred = model.predict(X_test)
print(f'y_true = {np.array(y_test)[:5]}')
print(f'y_pred = {y_pred[:5]}')
# Out:
# y_true = [5516. 5596. 5596. 5596. 5527.]
# y_pred = [5489.3135 5523.335  5553.5986 5553.3647 5494.6094]

# %%
predicted_prices = df_alk.loc[test_split_idx+1:].copy()
predicted_prices['close'] = y_pred

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df_alk.date, y=df_alk.close,
                         name='Truth',
                         marker_color='LightSkyBlue'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.date,
                         y=predicted_prices.close,
                         name='Prediction',
                         marker_color='MediumPurple'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.date,
                         y=y_test,
                         name='Truth',
                         marker_color='LightSkyBlue',
                         showlegend=False), row=2, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.date,
                         y=y_pred,
                         name='Prediction',
                         marker_color='MediumPurple',
                         showlegend=False), row=2, col=1)

fig.show()
# Out:
# <div>
#
#
#             <div id="8f0b6bdb-6d8c-4d00-bef4-a45356271bb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f0b6bdb-6d8c-4d00-bef4-a45356271bb8")) {
#                     Plotly.newPlot(
#                         '8f0b6bdb-6d8c-4d00-bef4-a45356271bb8',
#                         [{"marker": {"color": "LightSkyBlue"}, "name": "Truth", "type": "scatter", "x": ["1997-01-09T00:00:00", "1997-01-10T00:00:00", "1997-01-11T00:00:00", "1997-01-12T00:00:00", "1997-01-13T00:00:00", "1997-01-14T00:00:00", "1997-01-15T00:00:00", "1997-01-16T00:00:00", "1997-01-17T00:00:00", "1997-01-18T00:00:00", "1997-01-19T00:00:00", "1997-01-20T00:00:00", "1997-01-21T00:00:00", "1997-01-22T00:00:00", "1997-01-23T00:00:00", "1997-01-24T00:00:00", "1997-01-25T00:00:00", "1997-01-26T00:00:00", "1997-01-27T00:00:00", "1997-01-28T00:00:00", "1997-01-29T00:00:00", "1997-01-30T00:00:00", "1997-01-31T00:00:00", "1997-02-01T00:00:00", "1997-02-02T00:00:00", "1997-02-03T00:00:00", "1997-02-04T00:00:00", "1997-02-05T00:00:00", "1997-02-06T00:00:00", "1997-02-07T00:00:00", "1997-02-08T00:00:00", "1997-02-09T00:00:00", "1997-02-10T00:00:00", "1997-02-11T00:00:00", "1997-02-12T00:00:00", "1997-02-13T00:00:00", "1997-02-14T00:00:00", "1997-02-15T00:00:00", "1997-02-16T00:00:00", "1997-02-17T00:00:00", "1997-02-18T00:00:00", "1997-02-19T00:00:00", "1997-02-20T00:00:00", "1997-02-21T00:00:00", "1997-02-22T00:00:00", "1997-02-23T00:00:00", "1997-02-24T00:00:00", "1997-02-25T00:00:00", "1997-02-26T00:00:00", "1997-02-27T00:00:00", "1997-02-28T00:00:00", "1997-03-01T00:00:00", "1997-03-02T00:00:00", "1997-03-03T00:00:00", "1997-03-04T00:00:00", "1997-03-05T00:00:00", "1997-03-06T00:00:00", "1997-03-07T00:00:00", "1997-03-08T00:00:00", "1997-03-09T00:00:00", "1997-03-10T00:00:00", "1997-03-11T00:00:00", "1997-03-12T00:00:00", "1997-03-13T00:00:00", "1997-03-14T00:00:00", "1997-03-15T00:00:00", "1997-03-16T00:00:00", "1997-03-17T00:00:00", "1997-03-18T00:00:00", "1997-03-19T00:00:00", "1997-03-20T00:00:00", "1997-03-21T00:00:00", "1997-03-22T00:00:00", "1997-03-23T00:00:00", "1997-03-24T00:00:00", "1997-03-25T00:00:00", "1997-03-26T00:00:00", "1997-03-27T00:00:00", "1997-03-28T00:00:00", "1997-03-29T00:00:00", "1997-03-30T00:00:00", "1997-03-31T00:00:00", "1997-04-01T00:00:00", "1997-04-02T00:00:00", "1997-04-03T00:00:00", "1997-04-04T00:00:00", "1997-04-05T00:00:00", "1997-04-06T00:00:00", "1997-04-07T00:00:00", "1997-04-08T00:00:00", "1997-04-09T00:00:00", "1997-04-10T00:00:00", "1997-04-11T00:00:00", "1997-04-12T00:00:00", "1997-04-13T00:00:00", "1997-04-14T00:00:00", "1997-04-15T00:00:00", "1997-04-16T00:00:00", "1997-04-17T00:00:00", "1997-04-18T00:00:00", "1997-04-19T00:00:00", "1997-04-20T00:00:00", "1997-04-21T00:00:00", "1997-04-22T00:00:00", "1997-04-23T00:00:00", "1997-04-24T00:00:00", "1997-04-25T00:00:00", "1997-04-26T00:00:00", "1997-04-27T00:00:00", "1997-04-28T00:00:00", "1997-04-29T00:00:00", "1997-04-30T00:00:00", "1997-05-01T00:00:00", "1997-05-02T00:00:00", "1997-05-03T00:00:00", "1997-05-04T00:00:00", "1997-05-05T00:00:00", "1997-05-06T00:00:00", "1997-05-07T00:00:00", "1997-05-08T00:00:00", "1997-05-09T00:00:00", "1997-05-10T00:00:00", "1997-05-11T00:00:00", "1997-05-12T00:00:00", "1997-05-13T00:00:00", "1997-05-14T00:00:00", "1997-05-15T00:00:00", "1997-05-16T00:00:00", "1997-05-17T00:00:00", "1997-05-18T00:00:00", "1997-05-19T00:00:00", "1997-05-20T00:00:00", "1997-05-21T00:00:00", "1997-05-22T00:00:00", "1997-05-23T00:00:00", "1997-05-24T00:00:00", "1997-05-25T00:00:00", "1997-05-26T00:00:00", "1997-05-27T00:00:00", "1997-05-28T00:00:00", "1997-05-29T00:00:00", "1997-05-30T00:00:00", "1997-05-31T00:00:00", "1997-06-01T00:00:00", "1997-06-02T00:00:00", "1997-06-03T00:00:00", "1997-06-04T00:00:00", "1997-06-05T00:00:00", "1997-06-06T00:00:00", "1997-06-07T00:00:00", "1997-06-08T00:00:00", "1997-06-09T00:00:00", "1997-06-10T00:00:00", "1997-06-11T00:00:00", "1997-06-12T00:00:00", "1997-06-13T00:00:00", "1997-06-14T00:00:00", "1997-06-15T00:00:00", "1997-06-16T00:00:00", "1997-06-17T00:00:00", "1997-06-18T00:00:00", "1997-06-19T00:00:00", "1997-06-20T00:00:00", "1997-06-21T00:00:00", "1997-06-22T00:00:00", "1997-06-23T00:00:00", "1997-06-24T00:00:00", "1997-06-25T00:00:00", "1997-06-26T00:00:00", "1997-06 ...
